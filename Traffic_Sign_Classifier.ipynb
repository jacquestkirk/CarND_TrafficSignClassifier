# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data

training_file = r"C:\Users\Summer\Documents\projects\SDCND\IntroTensorFlow\CarND-Traffic-Sign-Classifier-Project\traffic-signs-data\train.p"
validation_file=r"C:\Users\Summer\Documents\projects\SDCND\IntroTensorFlow\CarND-Traffic-Sign-Classifier-Project\traffic-signs-data\valid.p"
testing_file = r"C:\Users\Summer\Documents\projects\SDCND\IntroTensorFlow\CarND-Traffic-Sign-Classifier-Project\traffic-signs-data\test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
print(max(y_train))
# Out:
# (34799, 32, 32, 3)
# (4410, 32, 32, 3)
# (12630, 32, 32, 3)
# 42

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results
import tensorflow as tf

# TODO: Number of training examples
n_train = X_train.shape[0]

# TODO: Number of validation examples
n_validation = X_valid.shape[0]

# TODO: Number of testing examples.
n_test = X_test.shape[0]

# TODO: What's the shape of an traffic sign image?
image_shape = X_test.shape[1:-1]

# TODO: How many unique classes/labels there are in the dataset.
n_classes = max(y_train) + 1

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

# %%
import random

#Print image
index = random.randint(0, len(X_train))
image = X_train[index].squeeze()

plt.figure(figsize=(1,1))
plt.imshow(image)
print(y_train[index])
# Out:
# 33

# %%
f, axarr = plt.subplots(5, 10)

print(axarr.size)
#print(X_train.shape)
size_list = []
for i in range(0, n_classes):
        #print(i)
        indices = (y_train == i)
        #print(indices.shape)
        example_images = X_train[indices]
        size_list.append(example_images.shape[0])
        rand_num = random.randint(0, len(example_images)-1)
        col = i % 10
        row = int(i / 10)
        
        #print(row)
        #print(col)
        
        image = example_images[rand_num].squeeze()
        #axarr[row][col] = plt.figure(figsize=(1,1))
        axarr[row][col].imshow(image)
        
plt.figure()
plt.plot(range(0,size_list.__len__()), size_list)
# Out:
# 50

# %%
#Print image
index = random.randint(0, len(X_train ))
image = X_train_norm_shuff[index].squeeze()

plt.figure(figsize=(1,1))
plt.imshow(image, cmap='gray')
print(y_train_shuff[index])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fdae5f993761> in <module>()
#       1 #Print image
#       2 index = random.randint(0, len(X_train ))
# ----> 3 image = X_train_norm_shuff[index].squeeze()
#       4
#       5 plt.figure(figsize=(1,1))
#
# NameError: name 'X_train_norm_shuff' is not defined

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
### Preprocess the data here. It is required to normalize the data. Other preprocessing steps could include 
### converting to grayscale, etc.
### Feel free to use as many code cells as needed.

# %%
#imports

import cv2
import numpy as np

# %%
#Preprocessing


def processImage(input_data):
    
    output_shape = (input_data.shape[0], 
                    input_data.shape[1], 
                    input_data.shape[2], 
                    1) 
    
    output_data = np.zeros_like(input_data, dtype=float)
    for i in range(0,output_shape[0]):
        for color in range(0,3):
        #create the output array, converting to grayscale, so depth is 1
            max_color = np.max(input_data[i,:,:,color])
            min_color = np.min(input_data[i,:,:,color])
            range_color = max_color - min_color


            color_data = (input_data[i,:,:,color]-min_color)/range_color - 0.5
            
            #for j in range(0,output_shape[1]):
            #    for k in range(0, output_shape[2]):

            #        output_data[i][j][k][color] = color_data[j][k]
           
            output_data[i,:,:,color] = np.copy(color_data)
        
            #plt.imshow(color_data.squeeze(), cmap ="gray")
            #plt.title(str(color))
        

    return output_data

X_train_norm = processImage(X_train)
X_valid_norm = processImage(X_valid)
X_test_norm = processImage(X_test)
    
    
print(X_train_norm.shape)
index = random.randint(0, len(X_train))
print(np.max(X_train_norm[index]))
print(np.min(X_train_norm[index]))
plt.figure()


plt.imshow(X_train_norm[index])
# Out:
# (34799, 32, 32, 3)
# 0.5
# -0.5

# %%
X_train_norm_sub = X_train_norm[5:10]
y_train_sub = y_train[5:10]

# %%
index = 250
plt.figure()
plt.imshow(X_train_norm[index].squeeze(), cmap='gray')
print(y_train[index])
# Out:
# 31

# %%
from sklearn.utils import shuffle

X_train_norm_shuff, y_train_shuff = shuffle(X_train_norm, y_train)

# %%
for image in X_train_norm_shuff[0:1000:250]:
    plt.figure()
    plt.imshow(image.squeeze(), cmap='gray')
print(y_train_shuff[0:1000:250])
# Out:
# [25 26  5  2]

# %% [markdown]
# ### Model Architecture

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.

# %%
from tensorflow.contrib.layers import flatten

class ConvLayerRelu:
    def __init__(self, kernelSize, depth, stride, pool = 1, padding = 'SAME'):
        self.kernelSize = kernelSize
        self.depth = depth
        self.stride = stride
        self.padding = padding
        self.pool = pool
        
    def getOutput(self, nodeInput):
        
        #instantiate weights and biases
        self.weights = tf.Variable(tf.truncated_normal((self.kernelSize, 
                                                        self.kernelSize, 
                                                        nodeInput.get_shape().as_list()[-1], 
                                                        self.depth)))
        self.biases = tf.Variable(tf.zeros(self.depth))
        
        size = self.kernelSize * self.kernelSize * nodeInput.get_shape().as_list()[-1]
        
        #convolutional layer
        strideList = [1,self.stride,self.stride,1]
        conv_output = tf.nn.conv2d(nodeInput, 
                                   self.weights, 
                                   strides = strideList, 
                                   padding = self.padding)
        
        #relu activation function
        relu_output = tf.nn.relu(tf.divide(conv_output, tf.constant(size, dtype='float32')))
        
        #pooling layer, if desired
        if not(self.pool > 1): #if pool is one or less, no pooling is desider
            self.output = relu_output
        else:
            
            poolSize = [1,self.pool, self.pool, 1]
            poolStride = poolSize
            poolPadding = 'VALID'
            
            pool_output = tf.nn.max_pool(conv_output, 
                            ksize = poolSize, 
                            strides = poolStride, 
                            padding = poolPadding)
            
            self.output = pool_output
        
        return pool_output
    
    def getFlatOutput(self):
        self.flatOutput = flatten(self.output)
            
        
        
        
class FullyConnectedLayer:
    def __init__(self, length):
        self.length = length
        
    def getOutput(self, nodeInput):
        
        self.weights = tf.Variable(tf.truncated_normal([nodeInput.get_shape().as_list()[1], self.length]))
        self.biases = tf.Variable(tf.zeros([self.length]))
        
        lin_output = tf.add(tf.matmul(nodeInput, self.weights), self.biases)
        
        size = nodeInput.get_shape().as_list()[1]
                                 
        self.output = tf.divide(lin_output, tf.constant(size, dtype='float32'))

# %%
def neuralNetwork(x, numClasses, keep_prob):
    
    conv1 = ConvLayerRelu(kernelSize=5,
                         depth = hyperParameters.conv1_depth,
                         stride = 1,
                         pool = 2,
                         padding = 'VALID')
    conv1.getOutput(x)
    print(conv1.output)
    
    conv2 = ConvLayerRelu(kernelSize=5,
                         depth = hyperParameters.conv2_depth,
                         stride = 1,
                         pool = 2,
                         padding = 'VALID') 
    conv2.getOutput(conv1.output)
    conv2.getFlatOutput()
    print(conv2.output)
    
    full1 = FullyConnectedLayer(hyperParameters.full1_len)
    full1.getOutput(conv2.flatOutput)
    print(full1.output)
    
    full2 = FullyConnectedLayer(hyperParameters.full2_len)
    full2.getOutput(full1.output)
    full2.output = tf.nn.dropout(full2.output, keep_prob)
    print(full2.output)
    
    output = FullyConnectedLayer(numClasses)
    output.getOutput(full2.output)
    print(output.output)
    
    logits = output.output
    
    print(logits)
    
    return logits

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.

# %%
class hyperParameterResults:
    def __init__(self):
        self.rate = -1
        self.batchSize = -1
        self.Epochs = -1
        self.conv1Depth = -1
        self.conv2Depth = -1
        self.full1Len = -1
        self.full2Len = -1
        self.keepProb = -1
        self.time = -1
        self.accuracy = -1
        self.accuracyList = []

# %%
import time

class NeuralNetworkRunner:
    
    def buildOptimizer(self):
        self.x = tf.placeholder(tf.float32, (None, 32, 32, 3))
        self.y = tf.placeholder(tf.int32, (None))
        self.one_hot_y = tf.one_hot(self.y, n_classes)
        self.keepProb = tf.placeholder(tf.float32)

        self.logits = neuralNetwork(self.x, numClasses=n_classes, keep_prob=self.keepProb)
        self.cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=self.one_hot_y, logits=self.logits)
        self.loss_operation = tf.reduce_mean(self.cross_entropy)
        self.optimizer = tf.train.AdamOptimizer(learning_rate = hyperParameters.rate)
        self.training_operation = self.optimizer.minimize(self.loss_operation)
        
    def buildEvaluator(self):
        self.saver = tf.train.Saver()
        self.correct_prediction = tf.equal(tf.argmax(self.logits, 1), tf.argmax(self.one_hot_y, 1))
        self.accuracy_operation = tf.reduce_mean(tf.cast(self.correct_prediction, tf.float32))
    
    def evaluate(self,X_data, y_data):
        num_examples = len(X_data)
        total_accuracy = 0
        sess = tf.get_default_session()
        for offset in range(0, num_examples, hyperParameters.batchSize):
            batch_x, batch_y = X_data[offset:offset+hyperParameters.batchSize], y_data[offset:offset+hyperParameters.batchSize]
            #print(batch_x.shape)
            #print(batch_y.shape)
            accuracy = sess.run(self.accuracy_operation, 
                                feed_dict={self.x: batch_x, self.y: batch_y, self.keepProb: 1})
            total_accuracy += (accuracy * len(batch_x))
        return total_accuracy / num_examples
    
    def runHyperParameterIteration(self):
    
        result = hyperParameterResults()

        with tf.Session() as sess:

            self.buildOptimizer()
            self.buildEvaluator()

            sess.run(tf.global_variables_initializer())
            num_examples = len(X_train_norm_shuff)

            print("Training...")
            print()

            old_accuracy = 0.0
            accuracy_list = []

            startTime = time.time()
            for i in range(hyperParameters.maxEpochs):
                X_train, y_train = shuffle(X_train_norm_shuff, y_train_shuff)
                for offset in range(0, num_examples, hyperParameters.batchSize):
                    end = offset + hyperParameters.batchSize
                    batch_x, batch_y = X_train[offset:end], y_train[offset:end]
                    sess.run(self.training_operation, 
                             feed_dict={self.x: batch_x, self.y: batch_y, self.keepProb: hyperParameters.keepProb})

                #validation_accuracy = evaluate(X_train_norm[0:100], y_train[0:100])
                validation_accuracy = self.evaluate(X_valid_norm, y_valid)
                print("EPOCH {} ...".format(i+1))
                print("Validation Accuracy = {:.3f}".format(validation_accuracy))
                print()



                accuracy_list.append(validation_accuracy)
                deltaAccuracy = validation_accuracy - old_accuracy
                numEpochs = i +1

                if((deltaAccuracy < searchParameters.minImprovement) & searchParameters.autoStop):
                    break

                old_accuracy = validation_accuracy

            stopTime = time.time()


            result.rate = hyperParameters.rate
            result.batchSize = hyperParameters.batchSize
            result.Epochs = numEpochs
            result.conv1Depth = hyperParameters.conv1_depth
            result.conv2Depth = hyperParameters.conv2_depth
            result.full1Len = hyperParameters.full1_len
            result.full2Len = hyperParameters.full2_len
            result.keepProb = hyperParameters.keepProb
            result.time =stopTime - startTime
            result.accuracy = validation_accuracy
            result.accuracyList = accuracy_list

            self.saver.save(sess, './lenet')
            print("Model saved")

            return result

# %%
class hyperParameters:
    rate = 0.005
    batchSize = 128
    maxEpochs = 50
    conv1_depth = 6
    conv2_depth = 50
    full1_len = 480
    full2_len = 125
    keepProb = 0.3

# %%
class searchParameters:
    minImprovement = 0.005
    autoStop = True

# %%
resultList = []

baseRate = hyperParameters.rate
for rate in [0.005, 0.01, 0.003]:
    hyperParameters.rate = rate
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.rate = baseRate

baseBatchSize = hyperParameters.batchSize
for batchSize in [256, 64, 128]:
    hyperParameters.batchSize = batchSize
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.batchSize = baseBatchSize

baseConv1Depth = hyperParameters.conv1_depth
for conv1_depth in [4, 6, 8]:
    hyperParameters.conv1_depth = conv1_depth
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.conv1_depth = baseConv1Depth

baseConv2Depth = hyperParameters.conv2_depth
for conv2_depth in [25, 100, 50]:
    hyperParameters.conv2_depth = conv2_depth
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.conv2_depth = baseConv2Depth

basefull1_len = hyperParameters.full1_len
for full1_len in [240, 480, 960]:
    hyperParameters.full1_len = full1_len
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.full1_len = basefull1_len

basefull2_len = hyperParameters.full2_len
for full2_len in [62, 125, 250]:
    hyperParameters.full2_len = full2_len
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.full2_len = basefull2_len

baseKeepProb = hyperParameters.keepProb
for keepProb in [0.25,0.3,0.4]:
    hyperParameters.keepProb = keepProb
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.keepProb = baseKeepProb
# Out:
# Tensor("MaxPool_102:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_103:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_13/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_51/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_15/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_15/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.685
#
# EPOCH 2 ...
# Validation Accuracy = 0.804
#
# EPOCH 3 ...
# Validation Accuracy = 0.851
#
# EPOCH 4 ...
# Validation Accuracy = 0.872
#
# EPOCH 5 ...
# Validation Accuracy = 0.880
#
# EPOCH 6 ...
# Validation Accuracy = 0.900
#
# EPOCH 7 ...
# Validation Accuracy = 0.895
#
# EPOCH 8 ...
# Validation Accuracy = 0.914
#
# EPOCH 9 ...
# Validation Accuracy = 0.916
#
# EPOCH 10 ...
# Validation Accuracy = 0.917
#
# EPOCH 11 ...
# Validation Accuracy = 0.924
#
# EPOCH 12 ...
# Validation Accuracy = 0.932
#
# EPOCH 13 ...
# Validation Accuracy = 0.928
#
# EPOCH 14 ...
# Validation Accuracy = 0.931
#
# EPOCH 15 ...
# Validation Accuracy = 0.933
#
# Model saved
# Tensor("MaxPool_104:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_105:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_18/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_52/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_20/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_20/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.785
#
# EPOCH 2 ...
# Validation Accuracy = 0.850
#
# EPOCH 3 ...
# Validation Accuracy = 0.889
#
# EPOCH 4 ...
# Validation Accuracy = 0.910
#
# EPOCH 5 ...
# Validation Accuracy = 0.916
#
# EPOCH 6 ...
# Validation Accuracy = 0.922
#
# EPOCH 7 ...
# Validation Accuracy = 0.932
#
# EPOCH 8 ...
# Validation Accuracy = 0.937
#
# EPOCH 9 ...
# Validation Accuracy = 0.933
#
# EPOCH 10 ...
# Validation Accuracy = 0.938
#
# EPOCH 11 ...
# Validation Accuracy = 0.948
#
# EPOCH 12 ...
# Validation Accuracy = 0.951
#
# EPOCH 13 ...
# Validation Accuracy = 0.948
#
# EPOCH 14 ...
# Validation Accuracy = 0.950
#
# EPOCH 15 ...
# Validation Accuracy = 0.956
#
# Model saved
# Tensor("MaxPool_106:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_107:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_23/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_53/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_25/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_25/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.445
#
# EPOCH 2 ...
# Validation Accuracy = 0.665
#
# EPOCH 3 ...
# Validation Accuracy = 0.729
#
# EPOCH 4 ...
# Validation Accuracy = 0.787
#
# EPOCH 5 ...
# Validation Accuracy = 0.812
#
# EPOCH 6 ...
# Validation Accuracy = 0.834
#
# EPOCH 7 ...
# Validation Accuracy = 0.846
#
# EPOCH 8 ...
# Validation Accuracy = 0.867
#
# EPOCH 9 ...
# Validation Accuracy = 0.870
#
# EPOCH 10 ...
# Validation Accuracy = 0.872
#
# EPOCH 11 ...
# Validation Accuracy = 0.868
#
# EPOCH 12 ...
# Validation Accuracy = 0.881
#
# EPOCH 13 ...
# Validation Accuracy = 0.885
#
# EPOCH 14 ...
# Validation Accuracy = 0.890
#
# EPOCH 15 ...
# Validation Accuracy = 0.899
#
# Model saved
# Tensor("MaxPool_108:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_109:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_28/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_54/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_30/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_30/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.495
#
# EPOCH 2 ...
# Validation Accuracy = 0.702
#
# EPOCH 3 ...
# Validation Accuracy = 0.778
#
# EPOCH 4 ...
# Validation Accuracy = 0.832
#
# EPOCH 5 ...
# Validation Accuracy = 0.844
#
# EPOCH 6 ...
# Validation Accuracy = 0.862
#
# EPOCH 7 ...
# Validation Accuracy = 0.880
#
# EPOCH 8 ...
# Validation Accuracy = 0.882
#
# EPOCH 9 ...
# Validation Accuracy = 0.875
#
# EPOCH 10 ...
# Validation Accuracy = 0.891
#
# EPOCH 11 ...
# Validation Accuracy = 0.903
#
# EPOCH 12 ...
# Validation Accuracy = 0.910
#
# EPOCH 13 ...
# Validation Accuracy = 0.914
#
# EPOCH 14 ...
# Validation Accuracy = 0.915
#
# EPOCH 15 ...
# Validation Accuracy = 0.923
#
# Model saved
# Tensor("MaxPool_110:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_111:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_33/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_55/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_35/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_35/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.770
#
# EPOCH 2 ...
# Validation Accuracy = 0.852
#
# EPOCH 3 ...
# Validation Accuracy = 0.888
#
# EPOCH 4 ...
# Validation Accuracy = 0.907
#
# EPOCH 5 ...
# Validation Accuracy = 0.925
#
# EPOCH 6 ...
# Validation Accuracy = 0.924
#
# EPOCH 7 ...
# Validation Accuracy = 0.928
#
# EPOCH 8 ...
# Validation Accuracy = 0.931
#
# EPOCH 9 ...
# Validation Accuracy = 0.942
#
# EPOCH 10 ...
# Validation Accuracy = 0.944
#
# EPOCH 11 ...
# Validation Accuracy = 0.948
#
# EPOCH 12 ...
# Validation Accuracy = 0.945
#
# EPOCH 13 ...
# Validation Accuracy = 0.941
#
# EPOCH 14 ...
# Validation Accuracy = 0.950
#
# EPOCH 15 ...
# Validation Accuracy = 0.941
#
# Model saved
# Tensor("MaxPool_112:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_113:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_38/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_56/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_40/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_40/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.666
#
# EPOCH 2 ...
# Validation Accuracy = 0.823
#
# EPOCH 3 ...
# Validation Accuracy = 0.862
#
# EPOCH 4 ...
# Validation Accuracy = 0.887
#
# EPOCH 5 ...
# Validation Accuracy = 0.892
#
# EPOCH 6 ...
# Validation Accuracy = 0.909
#
# EPOCH 7 ...
# Validation Accuracy = 0.923
#
# EPOCH 8 ...
# Validation Accuracy = 0.924
#
# EPOCH 9 ...
# Validation Accuracy = 0.928
#
# EPOCH 10 ...
# Validation Accuracy = 0.938
#
# EPOCH 11 ...
# Validation Accuracy = 0.941
#
# EPOCH 12 ...
# Validation Accuracy = 0.939
#
# EPOCH 13 ...
# Validation Accuracy = 0.943
#
# EPOCH 14 ...
# Validation Accuracy = 0.941
#
# EPOCH 15 ...
# Validation Accuracy = 0.940
#
# Model saved
# Tensor("MaxPool_114:0", shape=(?, 14, 14, 4), dtype=float32)
# Tensor("MaxPool_115:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_43/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_57/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_45/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_45/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.750
#
# EPOCH 2 ...
# Validation Accuracy = 0.843
#
# EPOCH 3 ...
# Validation Accuracy = 0.856
#
# EPOCH 4 ...
# Validation Accuracy = 0.890
#
# EPOCH 5 ...
# Validation Accuracy = 0.892
#
# EPOCH 6 ...
# Validation Accuracy = 0.914
#
# EPOCH 7 ...
# Validation Accuracy = 0.910
#
# EPOCH 8 ...
# Validation Accuracy = 0.918
#
# EPOCH 9 ...
# Validation Accuracy = 0.922
#
# EPOCH 10 ...
# Validation Accuracy = 0.929
#
# EPOCH 11 ...
# Validation Accuracy = 0.935
#
# EPOCH 12 ...
# Validation Accuracy = 0.940
#
# EPOCH 13 ...
# Validation Accuracy = 0.934
#
# EPOCH 14 ...
# Validation Accuracy = 0.940
#
# EPOCH 15 ...
# Validation Accuracy = 0.937
#
# Model saved
# Tensor("MaxPool_116:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_117:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_48/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_58/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_50/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_50/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.748
#
# EPOCH 2 ...
# Validation Accuracy = 0.838
#
# EPOCH 3 ...
# Validation Accuracy = 0.874
#
# EPOCH 4 ...
# Validation Accuracy = 0.906
#
# EPOCH 5 ...
# Validation Accuracy = 0.916
#
# EPOCH 6 ...
# Validation Accuracy = 0.914
#
# EPOCH 7 ...
# Validation Accuracy = 0.923
#
# EPOCH 8 ...
# Validation Accuracy = 0.935
#
# EPOCH 9 ...
# Validation Accuracy = 0.944
#
# EPOCH 10 ...
# Validation Accuracy = 0.939
#
# EPOCH 11 ...
# Validation Accuracy = 0.941
#
# EPOCH 12 ...
# Validation Accuracy = 0.951
#
# EPOCH 13 ...
# Validation Accuracy = 0.949
#
# EPOCH 14 ...
# Validation Accuracy = 0.954
#
# EPOCH 15 ...
# Validation Accuracy = 0.950
#
# Model saved
# Tensor("MaxPool_118:0", shape=(?, 14, 14, 8), dtype=float32)
# Tensor("MaxPool_119:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_53/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_59/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_55/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_55/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.758
#
# EPOCH 2 ...
# Validation Accuracy = 0.854
#
# EPOCH 3 ...
# Validation Accuracy = 0.891
#
# EPOCH 4 ...
# Validation Accuracy = 0.907
#
# EPOCH 5 ...
# Validation Accuracy = 0.916
#
# EPOCH 6 ...
# Validation Accuracy = 0.922
#
# EPOCH 7 ...
# Validation Accuracy = 0.919
#
# EPOCH 8 ...
# Validation Accuracy = 0.939
#
# EPOCH 9 ...
# Validation Accuracy = 0.939
#
# EPOCH 10 ...
# Validation Accuracy = 0.942
#
# EPOCH 11 ...
# Validation Accuracy = 0.951
#
# EPOCH 12 ...
# Validation Accuracy = 0.949
#
# EPOCH 13 ...
# Validation Accuracy = 0.951
#
# EPOCH 14 ...
# Validation Accuracy = 0.954
#
# EPOCH 15 ...
# Validation Accuracy = 0.944
#
# Model saved
# Tensor("MaxPool_120:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_121:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("Divide_58/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_60/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_60/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_60/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.779
#
# EPOCH 2 ...
# Validation Accuracy = 0.852
#
# EPOCH 3 ...
# Validation Accuracy = 0.892
#
# EPOCH 4 ...
# Validation Accuracy = 0.896
#
# EPOCH 5 ...
# Validation Accuracy = 0.913
#
# EPOCH 6 ...
# Validation Accuracy = 0.927
#
# EPOCH 7 ...
# Validation Accuracy = 0.928
#
# EPOCH 8 ...
# Validation Accuracy = 0.934
#
# EPOCH 9 ...
# Validation Accuracy = 0.945
#
# EPOCH 10 ...
# Validation Accuracy = 0.934
#
# EPOCH 11 ...
# Validation Accuracy = 0.942
#
# EPOCH 12 ...
# Validation Accuracy = 0.950
#
# EPOCH 13 ...
# Validation Accuracy = 0.934
#
# EPOCH 14 ...
# Validation Accuracy = 0.947
#
# EPOCH 15 ...
# Validation Accuracy = 0.948
#
# Model saved
# Tensor("MaxPool_122:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_123:0", shape=(?, 5, 5, 100), dtype=float32)
# Tensor("Divide_63/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_61/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_65/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_65/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.751
#
# EPOCH 2 ...
# Validation Accuracy = 0.859
#
# EPOCH 3 ...
# Validation Accuracy = 0.888
#
# EPOCH 4 ...
# Validation Accuracy = 0.899
#
# EPOCH 5 ...
# Validation Accuracy = 0.910
#
# EPOCH 6 ...
# Validation Accuracy = 0.913
#
# EPOCH 7 ...
# Validation Accuracy = 0.926
#
# EPOCH 8 ...
# Validation Accuracy = 0.937
#
# EPOCH 9 ...
# Validation Accuracy = 0.941
#
# EPOCH 10 ...
# Validation Accuracy = 0.944
#
# EPOCH 11 ...
# Validation Accuracy = 0.938
#
# EPOCH 12 ...
# Validation Accuracy = 0.946
#
# EPOCH 13 ...
# Validation Accuracy = 0.951
#
# EPOCH 14 ...
# Validation Accuracy = 0.949
#
# EPOCH 15 ...
# Validation Accuracy = 0.945
#
# Model saved
# Tensor("MaxPool_124:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_125:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_68/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_62/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_70/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_70/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.757
#
# EPOCH 2 ...
# Validation Accuracy = 0.832
#
# EPOCH 3 ...
# Validation Accuracy = 0.881
#
# EPOCH 4 ...
# Validation Accuracy = 0.904
#
# EPOCH 5 ...
# Validation Accuracy = 0.906
#
# EPOCH 6 ...
# Validation Accuracy = 0.929
#
# EPOCH 7 ...
# Validation Accuracy = 0.938
#
# EPOCH 8 ...
# Validation Accuracy = 0.938
#
# EPOCH 9 ...
# Validation Accuracy = 0.939
#
# EPOCH 10 ...
# Validation Accuracy = 0.947
#
# EPOCH 11 ...
# Validation Accuracy = 0.950
#
# EPOCH 12 ...
# Validation Accuracy = 0.947
#
# EPOCH 13 ...
# Validation Accuracy = 0.950
#
# EPOCH 14 ...
# Validation Accuracy = 0.953
#
# EPOCH 15 ...
# Validation Accuracy = 0.955
#
# Model saved
# Tensor("MaxPool_126:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_127:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_73/truediv:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_63/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_75/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_75/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.743
#
# EPOCH 2 ...
# Validation Accuracy = 0.856
#
# EPOCH 3 ...
# Validation Accuracy = 0.882
#
# EPOCH 4 ...
# Validation Accuracy = 0.900
#
# EPOCH 5 ...
# Validation Accuracy = 0.921
#
# EPOCH 6 ...
# Validation Accuracy = 0.937
#
# EPOCH 7 ...
# Validation Accuracy = 0.934
#
# EPOCH 8 ...
# Validation Accuracy = 0.944
#
# EPOCH 9 ...
# Validation Accuracy = 0.946
#
# EPOCH 10 ...
# Validation Accuracy = 0.948
#
# EPOCH 11 ...
# Validation Accuracy = 0.949
#
# EPOCH 12 ...
# Validation Accuracy = 0.952
#
# EPOCH 13 ...
# Validation Accuracy = 0.953
#
# EPOCH 14 ...
# Validation Accuracy = 0.961
#
# EPOCH 15 ...
# Validation Accuracy = 0.958
#
# Model saved
# Tensor("MaxPool_128:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_129:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_78/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_64/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_80/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_80/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.738
#
# EPOCH 2 ...
# Validation Accuracy = 0.849
#
# EPOCH 3 ...
# Validation Accuracy = 0.868
#
# EPOCH 4 ...
# Validation Accuracy = 0.901
#
# EPOCH 5 ...
# Validation Accuracy = 0.908
#
# EPOCH 6 ...
# Validation Accuracy = 0.922
#
# EPOCH 7 ...
# Validation Accuracy = 0.932
#
# EPOCH 8 ...
# Validation Accuracy = 0.936
#
# EPOCH 9 ...
# Validation Accuracy = 0.942
#
# EPOCH 10 ...
# Validation Accuracy = 0.954
#
# EPOCH 11 ...
# Validation Accuracy = 0.942
#
# EPOCH 12 ...
# Validation Accuracy = 0.947
#
# EPOCH 13 ...
# Validation Accuracy = 0.945
#
# EPOCH 14 ...
# Validation Accuracy = 0.944
#
# EPOCH 15 ...
# Validation Accuracy = 0.948
#
# Model saved
# Tensor("MaxPool_130:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_131:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_83/truediv:0", shape=(?, 960), dtype=float32)
# Tensor("dropout_65/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_85/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_85/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.780
#
# EPOCH 2 ...
# Validation Accuracy = 0.856
#
# EPOCH 3 ...
# Validation Accuracy = 0.891
#
# EPOCH 4 ...
# Validation Accuracy = 0.900
#
# EPOCH 5 ...
# Validation Accuracy = 0.914
#
# EPOCH 6 ...
# Validation Accuracy = 0.922
#
# EPOCH 7 ...
# Validation Accuracy = 0.918
#
# EPOCH 8 ...
# Validation Accuracy = 0.933
#
# EPOCH 9 ...
# Validation Accuracy = 0.921
#
# EPOCH 10 ...
# Validation Accuracy = 0.937
#
# EPOCH 11 ...
# Validation Accuracy = 0.943
#
# EPOCH 12 ...
# Validation Accuracy = 0.945
#
# EPOCH 13 ...
# Validation Accuracy = 0.950
#
# EPOCH 14 ...
# Validation Accuracy = 0.956
#
# EPOCH 15 ...
# Validation Accuracy = 0.948
#
# Model saved
# Tensor("MaxPool_132:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_133:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_88/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_66/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_90/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_90/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.775
#
# EPOCH 2 ...
# Validation Accuracy = 0.850
#
# EPOCH 3 ...
# Validation Accuracy = 0.891
#
# EPOCH 4 ...
# Validation Accuracy = 0.918
#
# EPOCH 5 ...
# Validation Accuracy = 0.915
#
# EPOCH 6 ...
# Validation Accuracy = 0.933
#
# EPOCH 7 ...
# Validation Accuracy = 0.939
#
# EPOCH 8 ...
# Validation Accuracy = 0.931
#
# EPOCH 9 ...
# Validation Accuracy = 0.947
#
# EPOCH 10 ...
# Validation Accuracy = 0.950
#
# EPOCH 11 ...
# Validation Accuracy = 0.942
#
# EPOCH 12 ...
# Validation Accuracy = 0.947
#
# EPOCH 13 ...
# Validation Accuracy = 0.947
#
# EPOCH 14 ...
# Validation Accuracy = 0.953
#
# EPOCH 15 ...
# Validation Accuracy = 0.950
#
# Model saved
# Tensor("MaxPool_134:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_135:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_93/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_67/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_95/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_95/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.749
#
# EPOCH 2 ...
# Validation Accuracy = 0.853
#
# EPOCH 3 ...
# Validation Accuracy = 0.891
#
# EPOCH 4 ...
# Validation Accuracy = 0.913
# EPOCH 5 ...
# Validation Accuracy = 0.924
#
# EPOCH 6 ...
# Validation Accuracy = 0.936
#
# EPOCH 7 ...
# Validation Accuracy = 0.934
#
# EPOCH 8 ...
# Validation Accuracy = 0.932
#
# EPOCH 9 ...
# Validation Accuracy = 0.945
#
# EPOCH 10 ...
# Validation Accuracy = 0.940
#
# EPOCH 11 ...
# Validation Accuracy = 0.939
#
# EPOCH 12 ...
# Validation Accuracy = 0.950
#
# EPOCH 13 ...
# Validation Accuracy = 0.933
#
# EPOCH 14 ...
# Validation Accuracy = 0.947
#
# EPOCH 15 ...
# Validation Accuracy = 0.950
#
# Model saved
# Tensor("MaxPool_136:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_137:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_98/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_68/mul:0", shape=(?, 250), dtype=float32)
# Tensor("Divide_100/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_100/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.759
#
# EPOCH 2 ...
# Validation Accuracy = 0.851
#
# EPOCH 3 ...
# Validation Accuracy = 0.878
#
# EPOCH 4 ...
# Validation Accuracy = 0.898
#
# EPOCH 5 ...
# Validation Accuracy = 0.913
#
# EPOCH 6 ...
# Validation Accuracy = 0.919
#
# EPOCH 7 ...
# Validation Accuracy = 0.927
#
# EPOCH 8 ...
# Validation Accuracy = 0.928
#
# EPOCH 9 ...
# Validation Accuracy = 0.927
#
# EPOCH 10 ...
# Validation Accuracy = 0.936
#
# EPOCH 11 ...
# Validation Accuracy = 0.941
#
# EPOCH 12 ...
# Validation Accuracy = 0.949
#
# EPOCH 13 ...
# Validation Accuracy = 0.938
#
# EPOCH 14 ...
# Validation Accuracy = 0.948
#
# EPOCH 15 ...
# Validation Accuracy = 0.946
#
# Model saved
# Tensor("MaxPool_138:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_139:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_103/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_69/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_105/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_105/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.745
#
# EPOCH 2 ...
# Validation Accuracy = 0.839
#
# EPOCH 3 ...
# Validation Accuracy = 0.882
#
# EPOCH 4 ...
# Validation Accuracy = 0.899
#
# EPOCH 5 ...
# Validation Accuracy = 0.918
#
# EPOCH 6 ...
# Validation Accuracy = 0.928
#
# EPOCH 7 ...
# Validation Accuracy = 0.935
#
# EPOCH 8 ...
# Validation Accuracy = 0.943
#
# EPOCH 9 ...
# Validation Accuracy = 0.946
#
# EPOCH 10 ...
# Validation Accuracy = 0.945
#
# EPOCH 11 ...
# Validation Accuracy = 0.949
#
# EPOCH 12 ...
# Validation Accuracy = 0.942
#
# EPOCH 13 ...
# Validation Accuracy = 0.945
#
# EPOCH 14 ...
# Validation Accuracy = 0.947
#
# EPOCH 15 ...
# Validation Accuracy = 0.948
#
# Model saved
# Tensor("MaxPool_140:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_141:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_108/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_70/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_110/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_110/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.779
#
# EPOCH 2 ...
# Validation Accuracy = 0.845
#
# EPOCH 3 ...
# Validation Accuracy = 0.874
#
# EPOCH 4 ...
# Validation Accuracy = 0.900
#
# EPOCH 5 ...
# Validation Accuracy = 0.907
#
# EPOCH 6 ...
# Validation Accuracy = 0.927
#
# EPOCH 7 ...
# Validation Accuracy = 0.917
#
# EPOCH 8 ...
# Validation Accuracy = 0.933
#
# EPOCH 9 ...
# Validation Accuracy = 0.945
#
# EPOCH 10 ...
# Validation Accuracy = 0.943
#
# EPOCH 11 ...
# Validation Accuracy = 0.937
#
# EPOCH 12 ...
# Validation Accuracy = 0.946
#
# EPOCH 13 ...
# Validation Accuracy = 0.941
#
# EPOCH 14 ...
# Validation Accuracy = 0.949
#
# EPOCH 15 ...
# Validation Accuracy = 0.953
#
# Model saved
# Tensor("MaxPool_142:0", shape=(?, 14, 14, 7), dtype=float32)
# Tensor("MaxPool_143:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("Divide_113/truediv:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_71/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_115/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_115/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.758
#
# EPOCH 2 ...
# Validation Accuracy = 0.855
#
# EPOCH 3 ...
# Validation Accuracy = 0.876
#
# EPOCH 4 ...
# Validation Accuracy = 0.892
#
# EPOCH 5 ...
# Validation Accuracy = 0.910
#
# EPOCH 6 ...
# Validation Accuracy = 0.924
#
# EPOCH 7 ...
# Validation Accuracy = 0.920
#
# EPOCH 8 ...
# Validation Accuracy = 0.938
#
# EPOCH 9 ...
# Validation Accuracy = 0.942
#
# EPOCH 10 ...
# Validation Accuracy = 0.947
#
# EPOCH 11 ...
# Validation Accuracy = 0.949
#
# EPOCH 12 ...
# Validation Accuracy = 0.951
#
# EPOCH 13 ...
# Validation Accuracy = 0.940
#
# EPOCH 14 ...
# Validation Accuracy = 0.948
#
# EPOCH 15 ...
# Validation Accuracy = 0.951
#
# Model saved

# %%
x_list = []
y_list = []

for result in resultList:
    x_list.append(result.time)
    y_list.append(result.accuracy)

print(x_list)
print(y_list)
plt.plot(x_list, y_list,'rx')
# Out:
# [945.3987681865692, 977.7934980392456, 981.8417675495148, 778.53493475914, 1013.6998519897461, 883.5367586612701, 973.4808161258698, 1013.8454415798187, 1028.9627797603607, 1011.6454854011536, 1256.8995282649994, 1104.6305544376373, 1051.7512106895447, 1111.371603012085, 1225.2232484817505, 1117.5632765293121, 1188.578703403473, 1430.9156556129456, 1215.221995830536, 1273.69651222229, 1266.1571893692017]
# [0.93287981859410429, 0.95600907005150026, 0.89886621290864321, 0.92290249408778147, 0.9408163265306122, 0.9399092970521542, 0.93718820888709586, 0.94988662134222435, 0.94376417211934827, 0.94784580525897799, 0.945124716553288, 0.95532879845625684, 0.95782312925170066, 0.94761904761904758, 0.94784580525897799, 0.9496598642158941, 0.94988662131519275, 0.94648526104129094, 0.94807256262859252, 0.95328798185941044, 0.95102040843358115]

# %%
#search for the hyperparameter space for the best result
class OptimizationGroup:
    rate = 0
    batchSize = 1
    conv1Depth = 2
    conv2Depth = 3
    full1Len = 4
    full2Len = 5
    keepProb = 6
    last = 7
    
groupName = {
    OptimizationGroup.rate:'rate',
    OptimizationGroup.batchSize:'batchSize',
    OptimizationGroup.conv1Depth:'conv1Depth',
    OptimizationGroup.conv2Depth:'conv2Depth',
    OptimizationGroup.full1Len:'full1Len',
    OptimizationGroup.full2Len:'full2Len',
    OptimizationGroup.keepProb:'keepProb'
}



sweepRound = 3


for group in range(0,OptimizationGroup.last):
    
    plt.figure()
    
    x_list = []
    y_list = []

    for result in resultList[group*3: group*3 + 3]:

        label = ("rate:" + str('%g' % result.rate) + "__" +
                 "batchSize:" + str(result.batchSize)+ "__" +
                 "conv1Depth" + str(result.conv1Depth)+ "__" +
                 "conv2Depth" + str(result.conv2Depth)+ "__" +
                 "full1Len" + str(result.full1Len)+ "__" +
                 "full2Len" + str(result.full2Len)+ "__" +
                 "keepProb" + str('%g' % result.keepProb) + 
                 "accuracy" + str('%.3f' % result.accuracy))
        
        plt.plot(range(0,result.accuracyList.__len__()), result.accuracyList, label = label)
        
        x_list.append(result.time)
        y_list.append(result.accuracy)
        
    
    name = "sweep " + groupName[group] + "_ round " + str(sweepRound) 
    
    plt.ylim([0.75,1])
    plt.xlim([0,20])
    plt.legend(bbox_to_anchor=(1.05, 1), loc=3, borderaxespad=0.)
    plt.title(name)
    plt.savefig(name, bbox_inches='tight')
    
    plt.figure()
    plt.plot(x_list, y_list,'rx')
    name = name + "_accuracyVsTime"
    plt.title(name)
    plt.savefig(name, bbox_inches='tight')

# %%
#store round results

f = open('resultList1.pck3', 'wb')
pickle.dump(resultList, f)
f.close()

# %%
print(result.rate)
print(result.batchSize)
print(result.Epochs)
print(result.conv1Depth)
print(result.conv2Depth)
print(result.full1Len)
print(result.full2Len)
print(result.keepProb)
print(result.time)
print(result.accuracy)
print(result.accuracyList)
# Out:
# 0.001
# 128
# 14
# 6
# 16
# 120
# 84
# 0.75
# 301.8270950317383
# 0.794331065408
# [0.35170068013695094, 0.49410430844408587, 0.57188208619483205, 0.61201814061660076, 0.66235827637367506, 0.68503401333512637, 0.7106575960745346, 0.72154195030259982, 0.74081632620623328, 0.75941043100119177, 0.76870748264178668, 0.78344671188298265, 0.78956916113289033, 0.79433106540822662]

# %%
class hyperParameters:
    rate = 0.01
    batchSize = 128
    maxEpochs = 15
    conv1_depth = 6
    conv2_depth = 25
    full1_len = 240
    full2_len = 62
    keepProb = 0.3

# %%
class searchParameters:
    minImprovement = 0.001
    autoStop = False

# %%
#run the final model

nnr = NeuralNetworkRunner()
result = nnr.runHyperParameterIteration()
# Out:
# Tensor("MaxPool:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_1:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("Divide_2/truediv:0", shape=(?, 240), dtype=float32)
# Tensor("dropout/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_4/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_4/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.640
#
# EPOCH 2 ...
# Validation Accuracy = 0.814
#
# EPOCH 3 ...
# Validation Accuracy = 0.837
#
# EPOCH 4 ...
# Validation Accuracy = 0.875
#
# EPOCH 5 ...
# Validation Accuracy = 0.881
#
# EPOCH 6 ...
# Validation Accuracy = 0.890
#
# EPOCH 7 ...
# Validation Accuracy = 0.907
#
# EPOCH 8 ...
# Validation Accuracy = 0.914
#
# EPOCH 9 ...
# Validation Accuracy = 0.917
#
# EPOCH 10 ...
# Validation Accuracy = 0.926
#
# EPOCH 11 ...
# Validation Accuracy = 0.925
#
# EPOCH 12 ...
# Validation Accuracy = 0.931
#
# EPOCH 13 ...
# Validation Accuracy = 0.938
#
# EPOCH 14 ...
# Validation Accuracy = 0.938
#
# EPOCH 15 ...
# Validation Accuracy = 0.938
#
# Model saved

# %%
print(result.accuracy)
# Out:
# 0.938321995465

# %%
#Validation Accuracy
with tf.Session() as sess:
    nnr.saver.restore(sess, tf.train.latest_checkpoint('.'))
    validation_accuracy = nnr.evaluate(X_valid_norm, y_valid)
    
print("Final Validation Accuracy = {:.3f}".format(validation_accuracy))
# Out:
# Final Validation Accuracy = 0.938

# %%
with tf.Session() as sess:
    nnr.saver.restore(sess, tf.train.latest_checkpoint('.'))
    test_accuracy = nnr.evaluate(X_test_norm, y_test)
    
print("Test Accuracy = {:.3f}".format(validation_accuracy))
# Out:
# Test Accuracy = 0.938

# %% [markdown]
# ---
#
# ## Step 2.5: Look at results

# %%
with tf.Session() as sess:
    nnr.saver.restore(sess, tf.train.latest_checkpoint('.'))
    logits = sess.run(nnr.logits, 
                        feed_dict={nnr.x: X_valid_norm, nnr.y: y_valid, nnr.keepProb: 1})

# %%
print(logits.shape)
print(y_valid.shape)
# Out:
# (4410, 43)
# (4410,)

# %%
#rows are what it should be, columns are what it is
error_count = np.zeros((n_classes, n_classes))


for i in range(0,y_valid.shape[0]):
    max_index = np.argmax(logits[i])
    if(max_index != y_valid[i]):
        print("incorrect index " + str(i) + ", should be "  + str(y_valid[i]) + ", got " + str(max_index))
        #print(type(y_valid[i]))
        #print(type(max_index))
        #print(error_count.shape)
        error_count[y_valid[i]][max_index] += 1
# Out:
# incorrect index 0, should be 41, got 32
# incorrect index 1, should be 41, got 32
# incorrect index 2, should be 41, got 32
# incorrect index 3, should be 41, got 32
# incorrect index 4, should be 41, got 32
# incorrect index 6, should be 41, got 32
# incorrect index 7, should be 41, got 32
# incorrect index 8, should be 41, got 32
# incorrect index 10, should be 41, got 32
# incorrect index 11, should be 41, got 32
# incorrect index 16, should be 41, got 32
# incorrect index 17, should be 41, got 32
# incorrect index 18, should be 41, got 32
# incorrect index 19, should be 41, got 32
# incorrect index 77, should be 31, got 21
# incorrect index 79, should be 31, got 23
# incorrect index 204, should be 26, got 11
# incorrect index 205, should be 26, got 18
# incorrect index 270, should be 23, got 20
# incorrect index 271, should be 23, got 20
# incorrect index 298, should be 23, got 17
# incorrect index 299, should be 23, got 20
# incorrect index 300, should be 1, got 2
# incorrect index 360, should be 1, got 2
# incorrect index 362, should be 1, got 2
# incorrect index 390, should be 1, got 4
# incorrect index 391, should be 1, got 4
# incorrect index 392, should be 1, got 2
# incorrect index 393, should be 1, got 4
# incorrect index 394, should be 1, got 4
# incorrect index 444, should be 1, got 4
# incorrect index 4306, should be 25, got 11
# incorrect index 4307, should be 25, got 11

# %%
#print common misconceptions

threshold = 5

for i in range(0, n_classes):
    for j in range(0, n_classes):
        if error_count[i][j] >= threshold:
            print("Class " + str(i) + " is incorrectly identified as " + str(j) + " " + str(error_count[i][j]) + " times.")
# Out:
# Class 0 is incorrectly identified as 4 11.0 times.
# Class 1 is incorrectly identified as 4 6.0 times.
# Class 2 is incorrectly identified as 1 11.0 times.
# Class 5 is incorrectly identified as 2 10.0 times.
# Class 7 is incorrectly identified as 5 20.0 times.
# Class 8 is incorrectly identified as 4 5.0 times.
# Class 16 is incorrectly identified as 41 13.0 times.
# Class 21 is incorrectly identified as 29 5.0 times.
# Class 21 is incorrectly identified as 31 24.0 times.
# Class 24 is incorrectly identified as 18 15.0 times.
# Class 27 is incorrectly identified as 18 11.0 times.
# Class 27 is incorrectly identified as 24 5.0 times.
# Class 34 is incorrectly identified as 38 5.0 times.
# Class 41 is incorrectly identified as 32 14.0 times.

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images
# Looks like the hardest to identify are
# - 8 (speed limit 120)
# - 41 (End of no passing)
# - 2 (speed limit 50)
# - 22 (bumpy road)
# - 33 (right turn ahead)

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.
import os
import matplotlib.image as mpimg

imageList = os.listdir("test_images\scaled")

print(imageList)

X_new = np.zeros((5,32,32,3))


for i in range(0,imageList.__len__()):
    image = imageList[i]
    image = mpimg.imread( "test_images/scaled/" +image)

    image_np = np.array(image)
    X_new[i] = np.copy(image_np)
    
    plt.figure()
    plt.imshow(image_np)

print(X_new.shape)
X_new_norm = processImage(X_new)
y_new = np.array([8,2,22,41,33])
# Out:
# ['120kph.jpg', '50kph.jpg', 'BumpyRoad.jpg', 'end_no_passing.jpg', 'RightTurn.jpg']
# (5, 32, 32, 3)

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
### Run the predictions here and use the model to output the prediction for each image.
### Make sure to pre-process the images with the same pre-processing pipeline used earlier.
### Feel free to use as many code cells as needed.

# %%
#get logits

with tf.Session() as sess:
    nnr.saver.restore(sess, tf.train.latest_checkpoint('.'))
    logits= sess.run(nnr.logits, 
                        feed_dict={nnr.x: X_new_norm, nnr.y: y_new, nnr.keepProb: 1})

# %%
print(logits)
# Out:
# [[ 20.29397964  20.08148956  15.85789776   7.2001586   23.39750481
#    13.86782551   0.9378584   15.59596062  22.89624596 -14.33119965
#   -13.61581516 -10.93792248 -22.84724998 -13.93061543   0.68372065
#     5.07984543  -2.37073827  -1.43487072  -0.57134396  -6.89101601
#    -6.89650393  -7.25411129 -10.51139069 -12.83656788   2.76483607
#    -5.36340284 -12.01644611  -0.21193543   2.09046745   5.53684616
#   -12.15314293   5.91991568  -5.40182066 -12.50110531 -22.83695602
#   -19.2528019   -7.48851871 -12.86782551  -7.90584755  -1.97798848
#    -2.32505584 -17.30460167 -12.47968292]
#  [  8.08918285  31.8723278   51.58086777  29.73764801  19.53805923
#    32.82248306   3.93049002  15.59611607   7.82587337 -17.58633041
#    -2.06578374 -12.30047703 -31.91877747  -5.30176497   4.08709812
#    -1.16327405 -14.24170685 -25.53853035 -13.19662189  -7.31365824
#   -12.6879549   -2.00687265 -32.71967697  -4.48565912  -4.13219833
#     5.59910345 -38.02233505  -3.00084543 -15.69511986  -6.90112877
#   -19.21225739  10.4540062  -23.81607819  -7.46184969 -20.43139839
#     1.89822870e-07   3.32671168e-10   3.04965731e-12   3.79161200e-08
#     3.40005903e-14   3.62553187e-08   1.56597495e-11]
#  [  8.80708058e-08   2.84682130e-07   5.83572216e-17   7.53584395e-09
#     2.82972168e-17   1.33547405e-12   2.23758161e-01   4.38834651e-13
#     1.64843132e-14   7.50289164e-15   3.12106429e-17   7.20535354e-07
#     1.62568128e-07   1.83314383e-15   1.88101652e-11   1.00220642e-15
#     3.84790127e-07   2.72632974e-06   1.27719753e-11   2.63430396e-16
#     2.73925380e-08   2.81861569e-16   2.89467559e-15   6.35194631e-12
#     6.38440073e-16   7.15862984e-14   9.43959266e-14   1.71190037e-12
#     3.82417866e-08   8.75948484e-14   3.35218908e-10   3.23424575e-17
#     7.59976089e-01   1.21261783e-17   1.94508631e-09   4.81703190e-15
#     1.73933330e-08   1.59044624e-16   1.14602938e-09   6.39779950e-19
#     8.92901031e-11   1.61334500e-02   1.27876207e-04]
#  [  3.25091313e-14   1.71119553e-12   2.25139511e-14   1.72350141e-20
#     1.29033299e-13   5.58425623e-22   4.01670608e-19   8.72479815e-19
#     1.09976268e-18   1.19093835e-18   5.20456346e-22   4.24473607e-12
#     3.79491605e-17   2.90279928e-18   2.93557685e-22   8.58430106e-17
#     8.88615704e-20   3.63290843e-17   2.19434150e-12   2.91277592e-11
#     5.91540666e-23   2.59001449e-11   1.21283091e-17   2.79151898e-19
#     6.34334870e-13   9.56774751e-18   2.78389182e-13   2.09407700e-10
#     9.76382654e-18   3.41093902e-18   9.90904881e-16   5.70139964e-13
#     4.43792283e-18   9.99904037e-01   6.50087785e-13   2.02640162e-12
#     5.00286839e-15   2.75226995e-07   1.02851598e-16   9.56834047e-05
#     1.72374541e-08   2.79035679e-20   5.43004591e-22]]
# [ 0.59242797  1.          0.77489293  0.75997609  0.99990404]
# index 0, should be 8, got 4
# index 1, should be 2, got 2
# index 2, should be 22, got 22
# index 3, should be 41, got 32
# index 4, should be 33, got 33

# %%
print(np.max(X_new_norm[1]))
print(np.min(X_new_norm[1]))
# Out:
# 0.5
# -0.5

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tf.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.

with tf.Session() as sess:
    nnr.saver.restore(sess, tf.train.latest_checkpoint('.'))
    top_vals = sess.run(tf.nn.top_k(tf.constant(logitsSoftMax), k=5))

# %%
print(top_vals)
# Out:
# TopKV2(values=array([[  5.92427969e-01,   3.58873665e-01,   2.65944917e-02,
#           2.15034653e-02,   3.14938545e-04],
#        [  1.00000000e+00,   7.13406445e-09,   2.75860712e-09,
#           3.26294824e-10,   1.21334708e-14],
#        [  7.74892926e-01,   1.29473895e-01,   5.98667152e-02,
#           1.84427183e-02,   1.39184529e-02],
#        [  7.59976089e-01,   2.23758161e-01,   1.61334500e-02,
#           1.27876207e-04,   2.72632974e-06],
#        [  9.99904037e-01,   9.56834047e-05,   2.75226995e-07,
#           1.72374541e-08,   2.09407700e-10]], dtype=float32), indices=array([[ 4,  8,  0,  1,  2],
#        [ 2,  5,  1,  3,  4],
#        [22, 30, 29, 34, 28],
#        [32,  6, 41, 42, 17],
#        [33, 39, 37, 40, 27]]))

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ---
#
# ## Step 4 (Optional): Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it may be having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")
