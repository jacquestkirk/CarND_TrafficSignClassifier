# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data

training_file = r"C:\Users\Summer\Documents\projects\SDCND\IntroTensorFlow\CarND-Traffic-Sign-Classifier-Project\traffic-signs-data\train.p"
validation_file=r"C:\Users\Summer\Documents\projects\SDCND\IntroTensorFlow\CarND-Traffic-Sign-Classifier-Project\traffic-signs-data\valid.p"
testing_file = r"C:\Users\Summer\Documents\projects\SDCND\IntroTensorFlow\CarND-Traffic-Sign-Classifier-Project\traffic-signs-data\test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
print(max(y_train))
# Out:
# (34799, 32, 32, 3)
# (4410, 32, 32, 3)
# (12630, 32, 32, 3)
# 42

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results
import tensorflow as tf

# TODO: Number of training examples
n_train = X_train.shape[0]

# TODO: Number of validation examples
n_validation = X_valid.shape[0]

# TODO: Number of testing examples.
n_test = X_test.shape[0]

# TODO: What's the shape of an traffic sign image?
image_shape = X_test.shape[1:-1]

# TODO: How many unique classes/labels there are in the dataset.
n_classes = max(y_train) + 1

print("Number of training examples =", n_train)
print("Number of validation examples =", n_validation)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of validation examples = 4410
# Number of testing examples = 12630
# Image data shape = (32, 32)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

# %%
import random

#Print image
index = random.randint(0, len(X_train))
image = X_train[index].squeeze()

plt.figure(figsize=(1,1))
plt.imshow(image)
print(y_train[index])
# Out:
# 29

# %%
#find a specific image
classNum = 37
index = 0
filtered_indicies = y_train == classNum
y_filt = y_train[filtered_indicies]
X_filt = X_train[filtered_indicies]

print(y_filt.shape)
print(X_filt.shape)

image = X_filt[index].squeeze()

plt.figure(figsize=(1,1))
plt.imshow(image)
print(y_filt[index])
# Out:
# (180,)
# (180, 32, 32, 3)
# 37

# %%
f, axarr = plt.subplots(5, 10)

print(axarr.size)
#print(X_train.shape)
size_list = []
for i in range(0, n_classes):
        #print(i)
        indices = (y_train == i)
        #print(indices.shape)
        example_images = X_train[indices]
        size_list.append(example_images.shape[0])
        rand_num = random.randint(0, len(example_images)-1)
        col = i % 10
        row = int(i / 10)
        
        #print(row)
        #print(col)
        
        image = example_images[rand_num].squeeze()
        #axarr[row][col] = plt.figure(figsize=(1,1))
        axarr[row][col].imshow(image)
        
plt.figure()
plt.plot(range(0,size_list.__len__()), size_list)
plt.title("Sign Frequeny")
plt.xlabel("Sign type")
plt.ylabel("Number of Samples")
# Out:
# 50

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
### Preprocess the data here. It is required to normalize the data. Other preprocessing steps could include 
### converting to grayscale, etc.
### Feel free to use as many code cells as needed.

# %%
#imports

import cv2
import numpy as np

# %%
#Preprocessing


def processImage(input_data):
    
    output_shape = (input_data.shape[0], 
                    input_data.shape[1], 
                    input_data.shape[2], 
                    1) 
    
    output_data = np.zeros_like(input_data, dtype=float)
    for i in range(0,output_shape[0]):
        for color in range(0,3):
        #create the output array, converting to grayscale, so depth is 1
            max_color = np.max(input_data[i,:,:,color])
            min_color = np.min(input_data[i,:,:,color])
            range_color = max_color - min_color


            color_data = (input_data[i,:,:,color]-min_color)/range_color - 0.5
            
            #for j in range(0,output_shape[1]):
            #    for k in range(0, output_shape[2]):

            #        output_data[i][j][k][color] = color_data[j][k]
           
            output_data[i,:,:,color] = np.copy(color_data)
        
            #plt.imshow(color_data.squeeze(), cmap ="gray")
            #plt.title(str(color))
        

    return output_data

X_train_norm = processImage(X_train)
X_valid_norm = processImage(X_valid)
X_test_norm = processImage(X_test)
    
    
print(X_train_norm.shape)
index = random.randint(0, len(X_train))
print(np.max(X_train_norm[index]))
print(np.min(X_train_norm[index]))
plt.figure()


plt.imshow(X_train_norm[index])
# Out:
# (34799, 32, 32, 3)
# 0.5
# -0.5

# %%
X_train_norm_sub = X_train_norm[5:10]
y_train_sub = y_train[5:10]

# %%
index = 250
plt.figure()
plt.imshow(X_train_norm[index].squeeze(), cmap='gray')
print(y_train[index])
# Out:
# 31

# %%
from sklearn.utils import shuffle

X_train_norm_shuff, y_train_shuff = shuffle(X_train_norm, y_train)

# %%
for image in X_train_norm_shuff[0:1000:250]:
    plt.figure()
    plt.imshow(image.squeeze(), cmap='gray')
print(y_train_shuff[0:1000:250])
# Out:
# [25 26  5  2]

# %% [markdown]
# ### Model Architecture

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.

# %%
from tensorflow.contrib.layers import flatten

class ConvLayerRelu:
    def __init__(self, kernelSize, depth, stride, pool = 1, padding = 'SAME'):
        self.kernelSize = kernelSize
        self.depth = depth
        self.stride = stride
        self.padding = padding
        self.pool = pool
        
    def getOutput(self, nodeInput):
        
        #instantiate weights and biases
        self.weights = tf.Variable(tf.truncated_normal((self.kernelSize, 
                                                        self.kernelSize, 
                                                        nodeInput.get_shape().as_list()[-1], 
                                                        self.depth)))
        self.biases = tf.Variable(tf.zeros(self.depth))
        
        size = self.kernelSize * self.kernelSize * nodeInput.get_shape().as_list()[-1]
        
        #convolutional layer
        strideList = [1,self.stride,self.stride,1]
        conv_output = tf.nn.conv2d(nodeInput, 
                                   self.weights, 
                                   strides = strideList, 
                                   padding = self.padding)
        
        #relu activation function
        relu_output = tf.nn.relu(tf.divide(conv_output, tf.constant(size, dtype='float32')))
        
        #pooling layer, if desired
        if not(self.pool > 1): #if pool is one or less, no pooling is desider
            self.output = relu_output
        else:
            
            poolSize = [1,self.pool, self.pool, 1]
            poolStride = poolSize
            poolPadding = 'VALID'
            
            pool_output = tf.nn.max_pool(conv_output, 
                            ksize = poolSize, 
                            strides = poolStride, 
                            padding = poolPadding)
            
            self.output = pool_output
        
        return pool_output
    
    def getFlatOutput(self):
        self.flatOutput = flatten(self.output)
            
        
        
        
class FullyConnectedLayer:
    def __init__(self, length):
        self.length = length
        
    def getOutput(self, nodeInput, outputNode = False):
        
        self.weights = tf.Variable(tf.truncated_normal([nodeInput.get_shape().as_list()[1], self.length]))
        self.biases = tf.Variable(tf.zeros([self.length]))
        
        lin_output = tf.add(tf.matmul(nodeInput, self.weights), self.biases)
        
        size = nodeInput.get_shape().as_list()[1]
        
        lin_output = tf.divide(lin_output, tf.constant(size, dtype='float32'))
        
        if outputNode:
            self.output = lin_output
        else:
            relu_output = tf.nn.relu(lin_output)

            self.output = relu_output

# %%
def neuralNetwork(x, numClasses, keep_prob):
    
    conv1 = ConvLayerRelu(kernelSize=5,
                         depth = hyperParameters.conv1_depth,
                         stride = 1,
                         pool = 2,
                         padding = 'VALID')
    conv1.getOutput(x)
    print(conv1.output)
    
    conv2 = ConvLayerRelu(kernelSize=5,
                         depth = hyperParameters.conv2_depth,
                         stride = 1,
                         pool = 2,
                         padding = 'VALID') 
    conv2.getOutput(conv1.output)
    conv2.getFlatOutput()
    print(conv2.output)
    
    full1 = FullyConnectedLayer(hyperParameters.full1_len)
    full1.getOutput(conv2.flatOutput)
    full1.output = tf.nn.dropout(full1.output, keep_prob)
    print(full1.output)
    
    full2 = FullyConnectedLayer(hyperParameters.full2_len)
    full2.getOutput(full1.output)
    full2.output = tf.nn.dropout(full2.output, keep_prob)
    print(full2.output)
    
    output = FullyConnectedLayer(numClasses)
    output.getOutput(full2.output, outputNode = True)
    print(output.output)
    
    logits = output.output
    
    print(logits)
    
    return logits

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.

# %%
class hyperParameterResults:
    def __init__(self):
        self.rate = -1
        self.batchSize = -1
        self.Epochs = -1
        self.conv1Depth = -1
        self.conv2Depth = -1
        self.full1Len = -1
        self.full2Len = -1
        self.keepProb = -1
        self.time = -1
        self.accuracy = -1
        self.trainAccuracyList = []
        self.accuracyList = []

# %%
import time

class NeuralNetworkRunner:
    
    def buildOptimizer(self):
        self.x = tf.placeholder(tf.float32, (None, 32, 32, 3))
        self.y = tf.placeholder(tf.int32, (None))
        self.one_hot_y = tf.one_hot(self.y, n_classes)
        self.keepProb = tf.placeholder(tf.float32)

        self.logits = neuralNetwork(self.x, numClasses=n_classes, keep_prob=self.keepProb)
        self.cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=self.one_hot_y, logits=self.logits)
        self.loss_operation = tf.reduce_mean(self.cross_entropy)
        self.optimizer = tf.train.AdamOptimizer(learning_rate = hyperParameters.rate)
        self.training_operation = self.optimizer.minimize(self.loss_operation)
        
    def buildEvaluator(self):
        self.saver = tf.train.Saver()
        self.correct_prediction = tf.equal(tf.argmax(self.logits, 1), tf.argmax(self.one_hot_y, 1))
        self.accuracy_operation = tf.reduce_mean(tf.cast(self.correct_prediction, tf.float32))
    
    def evaluate(self,X_data, y_data):
        num_examples = len(X_data)
        total_accuracy = 0
        sess = tf.get_default_session()
        for offset in range(0, num_examples, hyperParameters.batchSize):
            batch_x, batch_y = X_data[offset:offset+hyperParameters.batchSize], y_data[offset:offset+hyperParameters.batchSize]
            #print(batch_x.shape)
            #print(batch_y.shape)
            accuracy = sess.run(self.accuracy_operation, 
                                feed_dict={self.x: batch_x, self.y: batch_y, self.keepProb: 1})
            total_accuracy += (accuracy * len(batch_x))
        return total_accuracy / num_examples
    
    def runHyperParameterIteration(self):
    
        result = hyperParameterResults()

        with tf.Session() as sess:

            self.buildOptimizer()
            self.buildEvaluator()

            sess.run(tf.global_variables_initializer())
            num_examples = len(X_train_norm_shuff)

            print("Training...")
            print()

            old_accuracy = 0.0
            accuracy_list = []
            trainAccuracy_list = []

            startTime = time.time()
            for i in range(hyperParameters.maxEpochs):
                X_train, y_train = shuffle(X_train_norm_shuff, y_train_shuff)
                for offset in range(0, num_examples, hyperParameters.batchSize):
                    end = offset + hyperParameters.batchSize
                    batch_x, batch_y = X_train[offset:end], y_train[offset:end]
                    sess.run(self.training_operation, 
                             feed_dict={self.x: batch_x, self.y: batch_y, self.keepProb: hyperParameters.keepProb})

                #validation_accuracy = evaluate(X_train_norm[0:100], y_train[0:100])
                train_accuracy = nnr.evaluate(X_train_norm_shuff[0:1000], y_train_shuff[0:1000])
                validation_accuracy = self.evaluate(X_valid_norm, y_valid)
                
                print("EPOCH {} ...".format(i+1))
                print("Train Accuracy = {:.3f}".format(train_accuracy))
                print("Validation Accuracy = {:.3f}".format(validation_accuracy))
                print()



                accuracy_list.append(validation_accuracy)
                trainAccuracy_list.append(train_accuracy)
                
                deltaAccuracy = validation_accuracy - old_accuracy
                numEpochs = i +1

                if((deltaAccuracy < searchParameters.minImprovement) & searchParameters.autoStop):
                    break

                old_accuracy = validation_accuracy

            stopTime = time.time()


            result.rate = hyperParameters.rate
            result.batchSize = hyperParameters.batchSize
            result.Epochs = numEpochs
            result.conv1Depth = hyperParameters.conv1_depth
            result.conv2Depth = hyperParameters.conv2_depth
            result.full1Len = hyperParameters.full1_len
            result.full2Len = hyperParameters.full2_len
            result.keepProb = hyperParameters.keepProb
            result.time =stopTime - startTime
            result.accuracy = validation_accuracy
            result.accuracyList = accuracy_list
            result.trainAccuracy_list = trainAccuracy_list

            self.saver.save(sess, './lenet')
            print("Model saved")

            return result

# %%
class hyperParameters:
    rate = 0.01
    batchSize = 128
    maxEpochs = 20
    conv1_depth = 6
    conv2_depth = 25
    full1_len = 240
    full2_len = 62
    keepProb = 0.5

# %%
class searchParameters:
    minImprovement = 0.005
    autoStop = False

# %%
resultList = []

baseRate = hyperParameters.rate
for rate in [0.005, 0.01, 0.02]:
    hyperParameters.rate = rate
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.rate = baseRate

baseBatchSize = hyperParameters.batchSize
for batchSize in [64, 128, 256]:
    hyperParameters.batchSize = batchSize
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.batchSize = baseBatchSize

baseConv1Depth = hyperParameters.conv1_depth
for conv1_depth in [3, 6, 12]:
    hyperParameters.conv1_depth = conv1_depth
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.conv1_depth = baseConv1Depth

baseConv2Depth = hyperParameters.conv2_depth
for conv2_depth in [12, 25, 50]:
    hyperParameters.conv2_depth = conv2_depth
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.conv2_depth = baseConv2Depth

basefull1_len = hyperParameters.full1_len
for full1_len in [120, 240, 480]:
    hyperParameters.full1_len = full1_len
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.full1_len = basefull1_len

basefull2_len = hyperParameters.full2_len
for full2_len in [62, 125, 250]:
    hyperParameters.full2_len = full2_len
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.full2_len = basefull2_len

baseKeepProb = hyperParameters.keepProb
for keepProb in [0.2,0.4,0.8]:
    hyperParameters.keepProb = keepProb
    nnr = NeuralNetworkRunner()
    result = nnr.runHyperParameterIteration()
    resultList.append(result)
hyperParameters.keepProb = baseKeepProb
# Out:
# Tensor("MaxPool_30:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_31:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_17/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_18/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_78/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_78/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.353
# Validation Accuracy = 0.283
#
# EPOCH 2 ...
# Train Accuracy = 0.606
# Validation Accuracy = 0.572
#
# EPOCH 3 ...
# Train Accuracy = 0.732
# Validation Accuracy = 0.680
#
# EPOCH 4 ...
# Train Accuracy = 0.782
# Validation Accuracy = 0.754
#
# EPOCH 5 ...
# Train Accuracy = 0.829
# Validation Accuracy = 0.792
#
# EPOCH 6 ...
# Train Accuracy = 0.857
# Validation Accuracy = 0.811
#
# EPOCH 7 ...
# Train Accuracy = 0.871
# Validation Accuracy = 0.827
#
# EPOCH 8 ...
# Train Accuracy = 0.889
# Validation Accuracy = 0.838
#
# EPOCH 9 ...
# Train Accuracy = 0.899
# Validation Accuracy = 0.863
#
# EPOCH 10 ...
# Train Accuracy = 0.920
# Validation Accuracy = 0.864
#
# EPOCH 11 ...
# Train Accuracy = 0.921
# Validation Accuracy = 0.877
#
# EPOCH 12 ...
# Train Accuracy = 0.933
# Validation Accuracy = 0.877
#
# EPOCH 13 ...
# Train Accuracy = 0.941
# Validation Accuracy = 0.896
#
# EPOCH 14 ...
# Train Accuracy = 0.945
# Validation Accuracy = 0.897
#
# EPOCH 15 ...
# Train Accuracy = 0.953
# Validation Accuracy = 0.906
#
# EPOCH 16 ...
# Train Accuracy = 0.965
# Validation Accuracy = 0.912
#
# EPOCH 17 ...
# Train Accuracy = 0.956
# Validation Accuracy = 0.906
#
# EPOCH 18 ...
# Train Accuracy = 0.966
# Validation Accuracy = 0.912
#
# EPOCH 19 ...
# Train Accuracy = 0.967
# Validation Accuracy = 0.916
#
# EPOCH 20 ...
# Train Accuracy = 0.967
# Validation Accuracy = 0.921
#
# Tensor("MaxPool_32:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_33:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_19/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_20/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_83/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_83/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.535
# Validation Accuracy = 0.478
#
# EPOCH 2 ...
# Train Accuracy = 0.769
# Validation Accuracy = 0.707
#
# EPOCH 3 ...
# Train Accuracy = 0.840
# Validation Accuracy = 0.794
#
# EPOCH 4 ...
# Train Accuracy = 0.884
# Validation Accuracy = 0.832
#
# EPOCH 5 ...
# Train Accuracy = 0.914
# Validation Accuracy = 0.851
#
# EPOCH 6 ...
# Train Accuracy = 0.927
# Validation Accuracy = 0.870
#
# EPOCH 7 ...
# Train Accuracy = 0.937
# Validation Accuracy = 0.881
#
# EPOCH 8 ...
# Train Accuracy = 0.947
# Validation Accuracy = 0.889
#
# EPOCH 9 ...
# Train Accuracy = 0.964
# Validation Accuracy = 0.905
#
# EPOCH 10 ...
# Train Accuracy = 0.965
# Validation Accuracy = 0.909
#
# EPOCH 11 ...
# Train Accuracy = 0.972
# Validation Accuracy = 0.919
#
# EPOCH 12 ...
# Train Accuracy = 0.974
# Validation Accuracy = 0.917
#
# EPOCH 13 ...
# Train Accuracy = 0.977
# Validation Accuracy = 0.923
#
# EPOCH 14 ...
# Train Accuracy = 0.981
# Validation Accuracy = 0.922
#
# EPOCH 15 ...
# Train Accuracy = 0.980
# Validation Accuracy = 0.934
#
# EPOCH 16 ...
# Train Accuracy = 0.983
# Validation Accuracy = 0.935
#
# EPOCH 17 ...
# Train Accuracy = 0.985
# Validation Accuracy = 0.943
#
# EPOCH 18 ...
# Train Accuracy = 0.988
# Validation Accuracy = 0.940
#
# EPOCH 19 ...
# Train Accuracy = 0.987
# Validation Accuracy = 0.941
#
# EPOCH 20 ...
# Train Accuracy = 0.987
# Validation Accuracy = 0.942
#
# Tensor("MaxPool_34:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_35:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_21/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_22/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_88/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_88/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.698
# Validation Accuracy = 0.623
#
# EPOCH 2 ...
# Train Accuracy = 0.852
# Validation Accuracy = 0.801
#
# EPOCH 3 ...
# Train Accuracy = 0.907
# Validation Accuracy = 0.854
#
# EPOCH 4 ...
# Train Accuracy = 0.948
# Validation Accuracy = 0.893
#
# EPOCH 5 ...
# Train Accuracy = 0.962
# Validation Accuracy = 0.917
#
# EPOCH 6 ...
# Train Accuracy = 0.968
# Validation Accuracy = 0.929
#
# EPOCH 7 ...
# Train Accuracy = 0.979
# Validation Accuracy = 0.929
#
# EPOCH 8 ...
# Train Accuracy = 0.987
# Validation Accuracy = 0.935
#
# EPOCH 9 ...
# Train Accuracy = 0.983
# Validation Accuracy = 0.941
#
# EPOCH 10 ...
# Train Accuracy = 0.988
# Validation Accuracy = 0.944
#
# EPOCH 11 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.945
#
# EPOCH 12 ...
# Train Accuracy = 0.990
# Validation Accuracy = 0.943
#
# EPOCH 13 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.950
#
# EPOCH 14 ...
# Train Accuracy = 0.990
# Validation Accuracy = 0.946
#
# EPOCH 15 ...
# Train Accuracy = 0.993
# Validation Accuracy = 0.949
#
# EPOCH 16 ...
# Train Accuracy = 0.994
# Validation Accuracy = 0.958
#
# EPOCH 17 ...
# Train Accuracy = 0.995
# Validation Accuracy = 0.957
#
# EPOCH 18 ...
# Train Accuracy = 0.995
# Validation Accuracy = 0.961
#
# EPOCH 19 ...
# Train Accuracy = 0.998
# Validation Accuracy = 0.963
#
# EPOCH 20 ...
# Train Accuracy = 0.999
# Validation Accuracy = 0.964
#
# Tensor("MaxPool_36:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_37:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_23/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_24/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_93/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_93/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.686
# Validation Accuracy = 0.641
#
# EPOCH 2 ...
# Train Accuracy = 0.836
# Validation Accuracy = 0.787
#
# EPOCH 3 ...
# Train Accuracy = 0.883
# Validation Accuracy = 0.854
#
# EPOCH 4 ...
# Train Accuracy = 0.913
# Validation Accuracy = 0.879
#
# EPOCH 5 ...
# Train Accuracy = 0.935
# Validation Accuracy = 0.898
#
# EPOCH 6 ...
# Train Accuracy = 0.947
# Validation Accuracy = 0.903
#
# EPOCH 7 ...
# Train Accuracy = 0.969
# Validation Accuracy = 0.912
#
# EPOCH 8 ...
# Train Accuracy = 0.967
# Validation Accuracy = 0.916
#
# EPOCH 9 ...
# Train Accuracy = 0.975
# Validation Accuracy = 0.924
#
# EPOCH 10 ...
# Train Accuracy = 0.980
# Validation Accuracy = 0.928
#
# EPOCH 11 ...
# Train Accuracy = 0.985
# Validation Accuracy = 0.932
#
# EPOCH 12 ...
# Train Accuracy = 0.983
# Validation Accuracy = 0.933
#
# EPOCH 13 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.944
#
# EPOCH 14 ...
# Train Accuracy = 0.990
# Validation Accuracy = 0.944
#
# EPOCH 15 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.941
#
# EPOCH 16 ...
# Train Accuracy = 0.992
# Validation Accuracy = 0.947
#
# EPOCH 17 ...
# Train Accuracy = 0.994
# Validation Accuracy = 0.945
#
# EPOCH 18 ...
# Train Accuracy = 0.996
# Validation Accuracy = 0.949
#
# EPOCH 19 ...
# Train Accuracy = 0.993
# Validation Accuracy = 0.945
#
# EPOCH 20 ...
# Train Accuracy = 0.994
# Validation Accuracy = 0.949
#
# Tensor("MaxPool_38:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_39:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_25/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_26/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_98/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_98/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.572
# Validation Accuracy = 0.507
#
# EPOCH 2 ...
# Train Accuracy = 0.767
# Validation Accuracy = 0.706
#
# EPOCH 3 ...
# Train Accuracy = 0.856
# Validation Accuracy = 0.778
#
# EPOCH 4 ...
# Train Accuracy = 0.880
# Validation Accuracy = 0.820
#
# EPOCH 5 ...
# Train Accuracy = 0.908
# Validation Accuracy = 0.853
#
# EPOCH 6 ...
# Train Accuracy = 0.930
# Validation Accuracy = 0.865
#
# EPOCH 7 ...
# Train Accuracy = 0.943
# Validation Accuracy = 0.890
#
# EPOCH 8 ...
# Train Accuracy = 0.953
# Validation Accuracy = 0.896
#
# EPOCH 9 ...
# Train Accuracy = 0.957
# Validation Accuracy = 0.899
#
# EPOCH 10 ...
# Train Accuracy = 0.966
# Validation Accuracy = 0.912
#
# EPOCH 11 ...
# Train Accuracy = 0.964
# Validation Accuracy = 0.919
#
# EPOCH 12 ...
# Train Accuracy = 0.978
# Validation Accuracy = 0.924
#
# EPOCH 13 ...
# Train Accuracy = 0.974
# Validation Accuracy = 0.921
#
# EPOCH 14 ...
# Train Accuracy = 0.979
# Validation Accuracy = 0.926
#
# EPOCH 15 ...
# Train Accuracy = 0.981
# Validation Accuracy = 0.933
#
# EPOCH 16 ...
# Train Accuracy = 0.980
# Validation Accuracy = 0.930
#
# EPOCH 17 ...
# Train Accuracy = 0.985
# Validation Accuracy = 0.942
#
# EPOCH 18 ...
# Train Accuracy = 0.984
# Validation Accuracy = 0.941
#
# EPOCH 19 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.942
# EPOCH 20 ...
# Train Accuracy = 0.987
# Validation Accuracy = 0.944
#
# Tensor("MaxPool_40:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_41:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_27/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_28/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_103/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_103/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.373
# Validation Accuracy = 0.326
#
# EPOCH 2 ...
# Train Accuracy = 0.662
# Validation Accuracy = 0.615
#
# EPOCH 3 ...
# Train Accuracy = 0.769
# Validation Accuracy = 0.720
#
# EPOCH 4 ...
# Train Accuracy = 0.835
# Validation Accuracy = 0.786
#
# EPOCH 5 ...
# Train Accuracy = 0.859
# Validation Accuracy = 0.809
#
# EPOCH 6 ...
# Train Accuracy = 0.900
# Validation Accuracy = 0.835
#
# EPOCH 7 ...
# Train Accuracy = 0.901
# Validation Accuracy = 0.842
#
# EPOCH 8 ...
# Train Accuracy = 0.919
# Validation Accuracy = 0.857
#
# EPOCH 9 ...
# Train Accuracy = 0.933
# Validation Accuracy = 0.871
#
# EPOCH 10 ...
# Train Accuracy = 0.939
# Validation Accuracy = 0.874
#
# EPOCH 11 ...
# Train Accuracy = 0.953
# Validation Accuracy = 0.886
#
# EPOCH 12 ...
# Train Accuracy = 0.954
# Validation Accuracy = 0.890
#
# EPOCH 13 ...
# Train Accuracy = 0.953
# Validation Accuracy = 0.896
#
# EPOCH 14 ...
# Train Accuracy = 0.958
# Validation Accuracy = 0.910
#
# EPOCH 15 ...
# Train Accuracy = 0.962
# Validation Accuracy = 0.900
#
# EPOCH 16 ...
# Train Accuracy = 0.966
# Validation Accuracy = 0.914
#
# EPOCH 17 ...
# Train Accuracy = 0.964
# Validation Accuracy = 0.909
#
# EPOCH 18 ...
# Train Accuracy = 0.967
# Validation Accuracy = 0.919
#
# EPOCH 19 ...
# Train Accuracy = 0.963
# Validation Accuracy = 0.921
#
# EPOCH 20 ...
# Train Accuracy = 0.972
# Validation Accuracy = 0.925
#
# Tensor("MaxPool_42:0", shape=(?, 14, 14, 3), dtype=float32)
# Tensor("MaxPool_43:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_29/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_30/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_108/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_108/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.502
# Validation Accuracy = 0.450
#
# EPOCH 2 ...
# Train Accuracy = 0.740
# Validation Accuracy = 0.679
#
# EPOCH 3 ...
# Train Accuracy = 0.817
# Validation Accuracy = 0.765
#
# EPOCH 4 ...
# Train Accuracy = 0.862
# Validation Accuracy = 0.823
#
# EPOCH 5 ...
# Train Accuracy = 0.883
# Validation Accuracy = 0.847
#
# EPOCH 6 ...
# Train Accuracy = 0.919
# Validation Accuracy = 0.868
#
# EPOCH 7 ...
# Train Accuracy = 0.922
# Validation Accuracy = 0.876
#
# EPOCH 8 ...
# Train Accuracy = 0.935
# Validation Accuracy = 0.887
#
# EPOCH 9 ...
# Train Accuracy = 0.952
# Validation Accuracy = 0.903
#
# EPOCH 10 ...
# Train Accuracy = 0.957
# Validation Accuracy = 0.904
#
# EPOCH 11 ...
# Train Accuracy = 0.966
# Validation Accuracy = 0.915
#
# EPOCH 12 ...
# Train Accuracy = 0.964
# Validation Accuracy = 0.923
#
# EPOCH 13 ...
# Train Accuracy = 0.968
# Validation Accuracy = 0.928
#
# EPOCH 14 ...
# Train Accuracy = 0.980
# Validation Accuracy = 0.931
#
# EPOCH 15 ...
# Train Accuracy = 0.978
# Validation Accuracy = 0.924
#
# EPOCH 16 ...
# Train Accuracy = 0.969
# Validation Accuracy = 0.924
#
# EPOCH 17 ...
# Train Accuracy = 0.976
# Validation Accuracy = 0.931
#
# EPOCH 18 ...
# Train Accuracy = 0.979
# Validation Accuracy = 0.940
#
# EPOCH 19 ...
# Train Accuracy = 0.981
# Validation Accuracy = 0.941
#
# EPOCH 20 ...
# Train Accuracy = 0.981
# Validation Accuracy = 0.937
#
# Tensor("MaxPool_44:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_45:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_31/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_32/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_113/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_113/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.524
# Validation Accuracy = 0.481
#
# EPOCH 2 ...
# Train Accuracy = 0.748
# Validation Accuracy = 0.697
#
# EPOCH 3 ...
# Train Accuracy = 0.831
# Validation Accuracy = 0.777
#
# EPOCH 4 ...
# Train Accuracy = 0.867
# Validation Accuracy = 0.810
#
# EPOCH 5 ...
# Train Accuracy = 0.909
# Validation Accuracy = 0.856
#
# EPOCH 6 ...
# Train Accuracy = 0.922
# Validation Accuracy = 0.866
#
# EPOCH 7 ...
# Train Accuracy = 0.930
# Validation Accuracy = 0.881
#
# EPOCH 8 ...
# Train Accuracy = 0.949
# Validation Accuracy = 0.890
#
# EPOCH 9 ...
# Train Accuracy = 0.956
# Validation Accuracy = 0.898
#
# EPOCH 10 ...
# Train Accuracy = 0.964
# Validation Accuracy = 0.912
#
# EPOCH 11 ...
# Train Accuracy = 0.966
# Validation Accuracy = 0.905
#
# EPOCH 12 ...
# Train Accuracy = 0.971
# Validation Accuracy = 0.922
#
# EPOCH 13 ...
# Train Accuracy = 0.969
# Validation Accuracy = 0.930
#
# EPOCH 14 ...
# Train Accuracy = 0.974
# Validation Accuracy = 0.927
#
# EPOCH 15 ...
# Train Accuracy = 0.984
# Validation Accuracy = 0.928
#
# EPOCH 16 ...
# Train Accuracy = 0.987
# Validation Accuracy = 0.938
#
# EPOCH 17 ...
# Train Accuracy = 0.987
# Validation Accuracy = 0.940
#
# EPOCH 18 ...
# Train Accuracy = 0.980
# Validation Accuracy = 0.940
#
# EPOCH 19 ...
# Train Accuracy = 0.983
# Validation Accuracy = 0.945
#
# EPOCH 20 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.944
#
# Tensor("MaxPool_46:0", shape=(?, 14, 14, 12), dtype=float32)
# Tensor("MaxPool_47:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_33/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_34/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_118/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_118/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.578
# Validation Accuracy = 0.522
#
# EPOCH 2 ...
# Train Accuracy = 0.789
# Validation Accuracy = 0.727
#
# EPOCH 3 ...
# Train Accuracy = 0.851
# Validation Accuracy = 0.790
#
# EPOCH 4 ...
# Train Accuracy = 0.897
# Validation Accuracy = 0.848
#
# EPOCH 5 ...
# Train Accuracy = 0.921
# Validation Accuracy = 0.857
#
# EPOCH 6 ...
# Train Accuracy = 0.936
# Validation Accuracy = 0.881
#
# EPOCH 7 ...
# Train Accuracy = 0.954
# Validation Accuracy = 0.897
#
# EPOCH 8 ...
# Train Accuracy = 0.954
# Validation Accuracy = 0.896
#
# EPOCH 9 ...
# Train Accuracy = 0.969
# Validation Accuracy = 0.912
#
# EPOCH 10 ...
# Train Accuracy = 0.970
# Validation Accuracy = 0.908
#
# EPOCH 11 ...
# Train Accuracy = 0.971
# Validation Accuracy = 0.919
#
# EPOCH 12 ...
# Train Accuracy = 0.979
# Validation Accuracy = 0.921
#
# EPOCH 13 ...
# Train Accuracy = 0.981
# Validation Accuracy = 0.922
#
# EPOCH 14 ...
# Train Accuracy = 0.985
# Validation Accuracy = 0.927
#
# EPOCH 15 ...
# Train Accuracy = 0.980
# Validation Accuracy = 0.932
#
# EPOCH 16 ...
# Train Accuracy = 0.988
# Validation Accuracy = 0.930
#
# EPOCH 17 ...
# Train Accuracy = 0.985
# Validation Accuracy = 0.936
#
# EPOCH 18 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.940
#
# EPOCH 19 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.938
#
# EPOCH 20 ...
# Train Accuracy = 0.990
# Validation Accuracy = 0.943
#
# Tensor("MaxPool_48:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_49:0", shape=(?, 5, 5, 12), dtype=float32)
# Tensor("dropout_35/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_36/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_123/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_123/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.526
# Validation Accuracy = 0.481
#
# EPOCH 2 ...
# Train Accuracy = 0.726
# Validation Accuracy = 0.685
#
# EPOCH 3 ...
# Train Accuracy = 0.814
# Validation Accuracy = 0.776
#
# EPOCH 4 ...
# Train Accuracy = 0.875
# Validation Accuracy = 0.821
#
# EPOCH 5 ...
# Train Accuracy = 0.892
# Validation Accuracy = 0.842
#
# EPOCH 6 ...
# Train Accuracy = 0.917
# Validation Accuracy = 0.871
#
# EPOCH 7 ...
# Train Accuracy = 0.931
# Validation Accuracy = 0.881
#
# EPOCH 8 ...
# Train Accuracy = 0.947
# Validation Accuracy = 0.896
#
# EPOCH 9 ...
# Train Accuracy = 0.958
# Validation Accuracy = 0.898
#
# EPOCH 10 ...
# Train Accuracy = 0.955
# Validation Accuracy = 0.900
#
# EPOCH 11 ...
# Train Accuracy = 0.967
# Validation Accuracy = 0.911
#
# EPOCH 12 ...
# Train Accuracy = 0.965
# Validation Accuracy = 0.916
#
# EPOCH 13 ...
# Train Accuracy = 0.970
# Validation Accuracy = 0.916
#
# EPOCH 14 ...
# Train Accuracy = 0.970
# Validation Accuracy = 0.922
#
# EPOCH 15 ...
# Train Accuracy = 0.973
# Validation Accuracy = 0.924
#
# EPOCH 16 ...
# Train Accuracy = 0.976
# Validation Accuracy = 0.920
#
# EPOCH 17 ...
# Train Accuracy = 0.982
# Validation Accuracy = 0.929
#
# EPOCH 18 ...
# Train Accuracy = 0.984
# Validation Accuracy = 0.934
# EPOCH 19 ...
# Train Accuracy = 0.983
# Validation Accuracy = 0.932
#
# EPOCH 20 ...
# Train Accuracy = 0.987
# Validation Accuracy = 0.931
#
# Tensor("MaxPool_50:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_51:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_37/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_38/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_128/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_128/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.579
# Validation Accuracy = 0.536
#
# EPOCH 2 ...
# Train Accuracy = 0.767
# Validation Accuracy = 0.724
#
# EPOCH 3 ...
# Train Accuracy = 0.858
# Validation Accuracy = 0.803
#
# EPOCH 4 ...
# Train Accuracy = 0.890
# Validation Accuracy = 0.846
#
# EPOCH 5 ...
# Train Accuracy = 0.921
# Validation Accuracy = 0.867
#
# EPOCH 6 ...
# Train Accuracy = 0.938
# Validation Accuracy = 0.888
#
# EPOCH 7 ...
# Train Accuracy = 0.945
# Validation Accuracy = 0.902
#
# EPOCH 8 ...
# Train Accuracy = 0.953
# Validation Accuracy = 0.911
#
# EPOCH 9 ...
# Train Accuracy = 0.957
# Validation Accuracy = 0.920
#
# EPOCH 10 ...
# Train Accuracy = 0.969
# Validation Accuracy = 0.923
#
# EPOCH 11 ...
# Train Accuracy = 0.963
# Validation Accuracy = 0.924
#
# EPOCH 12 ...
# Train Accuracy = 0.977
# Validation Accuracy = 0.932
#
# EPOCH 13 ...
# Train Accuracy = 0.979
# Validation Accuracy = 0.928
#
# EPOCH 14 ...
# Train Accuracy = 0.982
# Validation Accuracy = 0.934
#
# EPOCH 15 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.938
#
# EPOCH 16 ...
# Train Accuracy = 0.982
# Validation Accuracy = 0.937
#
# EPOCH 17 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.938
#
# EPOCH 18 ...
# Train Accuracy = 0.984
# Validation Accuracy = 0.939
#
# EPOCH 19 ...
# Train Accuracy = 0.985
# Validation Accuracy = 0.949
#
# EPOCH 20 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.940
#
# Tensor("MaxPool_52:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_53:0", shape=(?, 5, 5, 50), dtype=float32)
# Tensor("dropout_39/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_40/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_133/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_133/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.549
# Validation Accuracy = 0.481
#
# EPOCH 2 ...
# Train Accuracy = 0.782
# Validation Accuracy = 0.739
#
# EPOCH 3 ...
# Train Accuracy = 0.854
# Validation Accuracy = 0.798
#
# EPOCH 4 ...
# Train Accuracy = 0.886
# Validation Accuracy = 0.837
#
# EPOCH 5 ...
# Train Accuracy = 0.913
# Validation Accuracy = 0.863
#
# EPOCH 6 ...
# Train Accuracy = 0.937
# Validation Accuracy = 0.878
#
# EPOCH 7 ...
# Train Accuracy = 0.945
# Validation Accuracy = 0.900
#
# EPOCH 8 ...
# Train Accuracy = 0.956
# Validation Accuracy = 0.896
#
# EPOCH 9 ...
# Train Accuracy = 0.964
# Validation Accuracy = 0.909
#
# EPOCH 10 ...
# Train Accuracy = 0.971
# Validation Accuracy = 0.926
#
# EPOCH 11 ...
# Train Accuracy = 0.978
# Validation Accuracy = 0.923
#
# EPOCH 12 ...
# Train Accuracy = 0.977
# Validation Accuracy = 0.923
#
# EPOCH 13 ...
# Train Accuracy = 0.982
# Validation Accuracy = 0.938
#
# EPOCH 14 ...
# Train Accuracy = 0.984
# Validation Accuracy = 0.931
#
# EPOCH 15 ...
# Train Accuracy = 0.988
# Validation Accuracy = 0.935
#
# EPOCH 16 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.941
#
# EPOCH 17 ...
# Train Accuracy = 0.992
# Validation Accuracy = 0.941
#
# EPOCH 18 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.943
#
# EPOCH 19 ...
# Train Accuracy = 0.991
# Validation Accuracy = 0.942
#
# EPOCH 20 ...
# Train Accuracy = 0.988
# Validation Accuracy = 0.944
#
# Tensor("MaxPool_54:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_55:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_41/mul:0", shape=(?, 120), dtype=float32)
# Tensor("dropout_42/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_138/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_138/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.492
# Validation Accuracy = 0.445
#
# EPOCH 2 ...
# Train Accuracy = 0.736
# Validation Accuracy = 0.675
#
# EPOCH 3 ...
# Train Accuracy = 0.821
# Validation Accuracy = 0.758
#
# EPOCH 4 ...
# Train Accuracy = 0.874
# Validation Accuracy = 0.804
#
# EPOCH 5 ...
# Train Accuracy = 0.900
# Validation Accuracy = 0.832
#
# EPOCH 6 ...
# Train Accuracy = 0.921
# Validation Accuracy = 0.865
#
# EPOCH 7 ...
# Train Accuracy = 0.932
# Validation Accuracy = 0.877
#
# EPOCH 8 ...
# Train Accuracy = 0.940
# Validation Accuracy = 0.890
#
# EPOCH 9 ...
# Train Accuracy = 0.950
# Validation Accuracy = 0.907
#
# EPOCH 10 ...
# Train Accuracy = 0.954
# Validation Accuracy = 0.910
#
# EPOCH 11 ...
# Train Accuracy = 0.964
# Validation Accuracy = 0.914
#
# EPOCH 12 ...
# Train Accuracy = 0.963
# Validation Accuracy = 0.925
#
# EPOCH 13 ...
# Train Accuracy = 0.976
# Validation Accuracy = 0.928
#
# EPOCH 14 ...
# Train Accuracy = 0.978
# Validation Accuracy = 0.917
#
# EPOCH 15 ...
# Train Accuracy = 0.974
# Validation Accuracy = 0.929
#
# EPOCH 16 ...
# Train Accuracy = 0.973
# Validation Accuracy = 0.936
#
# EPOCH 17 ...
# Train Accuracy = 0.983
# Validation Accuracy = 0.935
#
# EPOCH 18 ...
# Train Accuracy = 0.985
# Validation Accuracy = 0.938
#
# EPOCH 19 ...
# Train Accuracy = 0.985
# Validation Accuracy = 0.939
#
# EPOCH 20 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.934
#
# Tensor("MaxPool_56:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_57:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_43/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_44/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_143/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_143/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.560
# Validation Accuracy = 0.537
#
# EPOCH 2 ...
# Train Accuracy = 0.803
# Validation Accuracy = 0.770
#
# EPOCH 3 ...
# Train Accuracy = 0.864
# Validation Accuracy = 0.826
#
# EPOCH 4 ...
# Train Accuracy = 0.899
# Validation Accuracy = 0.863
#
# EPOCH 5 ...
# Train Accuracy = 0.920
# Validation Accuracy = 0.871
#
# EPOCH 6 ...
# Train Accuracy = 0.935
# Validation Accuracy = 0.888
#
# EPOCH 7 ...
# Train Accuracy = 0.957
# Validation Accuracy = 0.905
#
# EPOCH 8 ...
# Train Accuracy = 0.959
# Validation Accuracy = 0.916
#
# EPOCH 9 ...
# Train Accuracy = 0.960
# Validation Accuracy = 0.924
#
# EPOCH 10 ...
# Train Accuracy = 0.970
# Validation Accuracy = 0.927
#
# EPOCH 11 ...
# Train Accuracy = 0.972
# Validation Accuracy = 0.929
#
# EPOCH 12 ...
# Train Accuracy = 0.979
# Validation Accuracy = 0.932
#
# EPOCH 13 ...
# Train Accuracy = 0.982
# Validation Accuracy = 0.934
#
# EPOCH 14 ...
# Train Accuracy = 0.983
# Validation Accuracy = 0.937
#
# EPOCH 15 ...
# Train Accuracy = 0.982
# Validation Accuracy = 0.939
#
# EPOCH 16 ...
# Train Accuracy = 0.984
# Validation Accuracy = 0.945
#
# EPOCH 17 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.938
#
# EPOCH 18 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.945
#
# EPOCH 19 ...
# Train Accuracy = 0.987
# Validation Accuracy = 0.946
#
# EPOCH 20 ...
# Train Accuracy = 0.992
# Validation Accuracy = 0.951
#
# Tensor("MaxPool_58:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_59:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_45/mul:0", shape=(?, 480), dtype=float32)
# Tensor("dropout_46/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_148/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_148/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.555
# Validation Accuracy = 0.513
#
# EPOCH 2 ...
# Train Accuracy = 0.794
# Validation Accuracy = 0.729
#
# EPOCH 3 ...
# Train Accuracy = 0.854
# Validation Accuracy = 0.810
#
# EPOCH 4 ...
# Train Accuracy = 0.883
# Validation Accuracy = 0.837
#
# EPOCH 5 ...
# Train Accuracy = 0.918
# Validation Accuracy = 0.870
#
# EPOCH 6 ...
# Train Accuracy = 0.949
# Validation Accuracy = 0.885
#
# EPOCH 7 ...
# Train Accuracy = 0.959
# Validation Accuracy = 0.900
#
# EPOCH 8 ...
# Train Accuracy = 0.954
# Validation Accuracy = 0.912
#
# EPOCH 9 ...
# Train Accuracy = 0.969
# Validation Accuracy = 0.915
#
# EPOCH 10 ...
# Train Accuracy = 0.969
# Validation Accuracy = 0.921
#
# EPOCH 11 ...
# Train Accuracy = 0.979
# Validation Accuracy = 0.926
#
# EPOCH 12 ...
# Train Accuracy = 0.977
# Validation Accuracy = 0.926
#
# EPOCH 13 ...
# Train Accuracy = 0.977
# Validation Accuracy = 0.933
#
# EPOCH 14 ...
# Train Accuracy = 0.984
# Validation Accuracy = 0.928
#
# EPOCH 15 ...
# Train Accuracy = 0.983
# Validation Accuracy = 0.934
#
# EPOCH 16 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.941
#
# EPOCH 17 ...
# Train Accuracy = 0.987
# Validation Accuracy = 0.939
# EPOCH 18 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.944
#
# EPOCH 19 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.940
#
# EPOCH 20 ...
# Train Accuracy = 0.992
# Validation Accuracy = 0.944
#
# Tensor("MaxPool_60:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_61:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_47/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_48/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_153/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_153/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.553
# Validation Accuracy = 0.508
#
# EPOCH 2 ...
# Train Accuracy = 0.761
# Validation Accuracy = 0.716
#
# EPOCH 3 ...
# Train Accuracy = 0.847
# Validation Accuracy = 0.785
#
# EPOCH 4 ...
# Train Accuracy = 0.881
# Validation Accuracy = 0.826
#
# EPOCH 5 ...
# Train Accuracy = 0.909
# Validation Accuracy = 0.859
#
# EPOCH 6 ...
# Train Accuracy = 0.923
# Validation Accuracy = 0.869
#
# EPOCH 7 ...
# Train Accuracy = 0.935
# Validation Accuracy = 0.878
#
# EPOCH 8 ...
# Train Accuracy = 0.949
# Validation Accuracy = 0.887
#
# EPOCH 9 ...
# Train Accuracy = 0.960
# Validation Accuracy = 0.896
#
# EPOCH 10 ...
# Train Accuracy = 0.964
# Validation Accuracy = 0.908
#
# EPOCH 11 ...
# Train Accuracy = 0.967
# Validation Accuracy = 0.909
#
# EPOCH 12 ...
# Train Accuracy = 0.971
# Validation Accuracy = 0.917
#
# EPOCH 13 ...
# Train Accuracy = 0.972
# Validation Accuracy = 0.922
#
# EPOCH 14 ...
# Train Accuracy = 0.980
# Validation Accuracy = 0.921
#
# EPOCH 15 ...
# Train Accuracy = 0.975
# Validation Accuracy = 0.932
#
# EPOCH 16 ...
# Train Accuracy = 0.982
# Validation Accuracy = 0.931
#
# EPOCH 17 ...
# Train Accuracy = 0.984
# Validation Accuracy = 0.935
#
# EPOCH 18 ...
# Train Accuracy = 0.983
# Validation Accuracy = 0.932
#
# EPOCH 19 ...
# Train Accuracy = 0.983
# Validation Accuracy = 0.941
#
# EPOCH 20 ...
# Train Accuracy = 0.982
# Validation Accuracy = 0.937
#
# Tensor("MaxPool_62:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_63:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_49/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_50/mul:0", shape=(?, 125), dtype=float32)
# Tensor("Divide_158/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_158/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.579
# Validation Accuracy = 0.525
#
# EPOCH 2 ...
# Train Accuracy = 0.777
# Validation Accuracy = 0.727
#
# EPOCH 3 ...
# Train Accuracy = 0.860
# Validation Accuracy = 0.814
#
# EPOCH 4 ...
# Train Accuracy = 0.891
# Validation Accuracy = 0.849
#
# EPOCH 5 ...
# Train Accuracy = 0.912
# Validation Accuracy = 0.856
#
# EPOCH 6 ...
# Train Accuracy = 0.927
# Validation Accuracy = 0.877
#
# EPOCH 7 ...
# Train Accuracy = 0.949
# Validation Accuracy = 0.894
#
# EPOCH 8 ...
# Train Accuracy = 0.954
# Validation Accuracy = 0.899
#
# EPOCH 9 ...
# Train Accuracy = 0.958
# Validation Accuracy = 0.915
#
# EPOCH 10 ...
# Train Accuracy = 0.967
# Validation Accuracy = 0.916
#
# EPOCH 11 ...
# Train Accuracy = 0.971
# Validation Accuracy = 0.918
#
# EPOCH 12 ...
# Train Accuracy = 0.970
# Validation Accuracy = 0.922
#
# EPOCH 13 ...
# Train Accuracy = 0.975
# Validation Accuracy = 0.930
#
# EPOCH 14 ...
# Train Accuracy = 0.980
# Validation Accuracy = 0.928
#
# EPOCH 15 ...
# Train Accuracy = 0.980
# Validation Accuracy = 0.923
#
# EPOCH 16 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.933
#
# EPOCH 17 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.934
#
# EPOCH 18 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.940
#
# EPOCH 19 ...
# Train Accuracy = 0.988
# Validation Accuracy = 0.932
#
# EPOCH 20 ...
# Train Accuracy = 0.991
# Validation Accuracy = 0.932
#
# Tensor("MaxPool_64:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_65:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_51/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_52/mul:0", shape=(?, 250), dtype=float32)
# Tensor("Divide_163/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_163/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.598
# Validation Accuracy = 0.541
#
# EPOCH 2 ...
# Train Accuracy = 0.803
# Validation Accuracy = 0.755
#
# EPOCH 3 ...
# Train Accuracy = 0.866
# Validation Accuracy = 0.828
#
# EPOCH 4 ...
# Train Accuracy = 0.905
# Validation Accuracy = 0.859
#
# EPOCH 5 ...
# Train Accuracy = 0.921
# Validation Accuracy = 0.863
#
# EPOCH 6 ...
# Train Accuracy = 0.943
# Validation Accuracy = 0.878
#
# EPOCH 7 ...
# Train Accuracy = 0.945
# Validation Accuracy = 0.897
#
# EPOCH 8 ...
# Train Accuracy = 0.962
# Validation Accuracy = 0.893
#
# EPOCH 9 ...
# Train Accuracy = 0.971
# Validation Accuracy = 0.909
#
# EPOCH 10 ...
# Train Accuracy = 0.968
# Validation Accuracy = 0.909
#
# EPOCH 11 ...
# Train Accuracy = 0.976
# Validation Accuracy = 0.915
#
# EPOCH 12 ...
# Train Accuracy = 0.981
# Validation Accuracy = 0.921
#
# EPOCH 13 ...
# Train Accuracy = 0.991
# Validation Accuracy = 0.924
#
# EPOCH 14 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.925
#
# EPOCH 15 ...
# Train Accuracy = 0.990
# Validation Accuracy = 0.932
#
# EPOCH 16 ...
# Train Accuracy = 0.991
# Validation Accuracy = 0.935
#
# EPOCH 17 ...
# Train Accuracy = 0.984
# Validation Accuracy = 0.936
#
# EPOCH 18 ...
# Train Accuracy = 0.992
# Validation Accuracy = 0.931
#
# EPOCH 19 ...
# Train Accuracy = 0.993
# Validation Accuracy = 0.942
#
# EPOCH 20 ...
# Train Accuracy = 0.994
# Validation Accuracy = 0.936
#
# Tensor("MaxPool_66:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_67:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_53/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_54/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_168/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_168/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.243
# Validation Accuracy = 0.216
#
# EPOCH 2 ...
# Train Accuracy = 0.472
# Validation Accuracy = 0.444
#
# EPOCH 3 ...
# Train Accuracy = 0.511
# Validation Accuracy = 0.449
#
# EPOCH 4 ...
# Train Accuracy = 0.591
# Validation Accuracy = 0.537
#
# EPOCH 5 ...
# Train Accuracy = 0.593
# Validation Accuracy = 0.564
#
# EPOCH 6 ...
# Train Accuracy = 0.601
# Validation Accuracy = 0.568
#
# EPOCH 7 ...
# Train Accuracy = 0.649
# Validation Accuracy = 0.599
#
# EPOCH 8 ...
# Train Accuracy = 0.699
# Validation Accuracy = 0.652
#
# EPOCH 9 ...
# Train Accuracy = 0.687
# Validation Accuracy = 0.646
#
# EPOCH 10 ...
# Train Accuracy = 0.728
# Validation Accuracy = 0.688
#
# EPOCH 11 ...
# Train Accuracy = 0.774
# Validation Accuracy = 0.739
#
# EPOCH 12 ...
# Train Accuracy = 0.793
# Validation Accuracy = 0.759
#
# EPOCH 13 ...
# Train Accuracy = 0.809
# Validation Accuracy = 0.762
#
# EPOCH 14 ...
# Train Accuracy = 0.817
# Validation Accuracy = 0.781
#
# EPOCH 15 ...
# Train Accuracy = 0.829
# Validation Accuracy = 0.784
#
# EPOCH 16 ...
# Train Accuracy = 0.839
# Validation Accuracy = 0.788
#
# EPOCH 17 ...
# Train Accuracy = 0.842
# Validation Accuracy = 0.793
#
# EPOCH 18 ...
# Train Accuracy = 0.849
# Validation Accuracy = 0.802
#
# EPOCH 19 ...
# Train Accuracy = 0.862
# Validation Accuracy = 0.807
#
# EPOCH 20 ...
# Train Accuracy = 0.860
# Validation Accuracy = 0.816
#
# Tensor("MaxPool_68:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_69:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_55/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_56/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_173/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_173/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.503
# Validation Accuracy = 0.451
#
# EPOCH 2 ...
# Train Accuracy = 0.683
# Validation Accuracy = 0.644
#
# EPOCH 3 ...
# Train Accuracy = 0.793
# Validation Accuracy = 0.744
#
# EPOCH 4 ...
# Train Accuracy = 0.831
# Validation Accuracy = 0.786
#
# EPOCH 5 ...
# Train Accuracy = 0.869
# Validation Accuracy = 0.828
#
# EPOCH 6 ...
# Train Accuracy = 0.883
# Validation Accuracy = 0.837
#
# EPOCH 7 ...
# Train Accuracy = 0.912
# Validation Accuracy = 0.861
#
# EPOCH 8 ...
# Train Accuracy = 0.918
# Validation Accuracy = 0.869
#
# EPOCH 9 ...
# Train Accuracy = 0.926
# Validation Accuracy = 0.891
#
# EPOCH 10 ...
# Train Accuracy = 0.938
# Validation Accuracy = 0.903
#
# EPOCH 11 ...
# Train Accuracy = 0.948
# Validation Accuracy = 0.914
#
# EPOCH 12 ...
# Train Accuracy = 0.958
# Validation Accuracy = 0.920
#
# EPOCH 13 ...
# Train Accuracy = 0.969
# Validation Accuracy = 0.915
#
# EPOCH 14 ...
# Train Accuracy = 0.970
# Validation Accuracy = 0.921
#
# EPOCH 15 ...
# Train Accuracy = 0.974
# Validation Accuracy = 0.927
#
# EPOCH 16 ...
# Train Accuracy = 0.979
# Validation Accuracy = 0.928
# EPOCH 17 ...
# Train Accuracy = 0.976
# Validation Accuracy = 0.931
#
# EPOCH 18 ...
# Train Accuracy = 0.978
# Validation Accuracy = 0.931
#
# EPOCH 19 ...
# Train Accuracy = 0.984
# Validation Accuracy = 0.942
#
# EPOCH 20 ...
# Train Accuracy = 0.980
# Validation Accuracy = 0.943
#
# Tensor("MaxPool_70:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_71:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_57/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_58/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_178/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_178/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.700
# Validation Accuracy = 0.616
#
# EPOCH 2 ...
# Train Accuracy = 0.842
# Validation Accuracy = 0.757
#
# EPOCH 3 ...
# Train Accuracy = 0.889
# Validation Accuracy = 0.826
#
# EPOCH 4 ...
# Train Accuracy = 0.915
# Validation Accuracy = 0.842
#
# EPOCH 5 ...
# Train Accuracy = 0.940
# Validation Accuracy = 0.861
#
# EPOCH 6 ...
# Train Accuracy = 0.958
# Validation Accuracy = 0.873
#
# EPOCH 7 ...
# Train Accuracy = 0.962
# Validation Accuracy = 0.891
#
# EPOCH 8 ...
# Train Accuracy = 0.964
# Validation Accuracy = 0.890
#
# EPOCH 9 ...
# Train Accuracy = 0.974
# Validation Accuracy = 0.889
#
# EPOCH 10 ...
# Train Accuracy = 0.979
# Validation Accuracy = 0.908
#
# EPOCH 11 ...
# Train Accuracy = 0.985
# Validation Accuracy = 0.904
#
# EPOCH 12 ...
# Train Accuracy = 0.987
# Validation Accuracy = 0.917
#
# EPOCH 13 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.912
#
# EPOCH 14 ...
# Train Accuracy = 0.993
# Validation Accuracy = 0.922
#
# EPOCH 15 ...
# Train Accuracy = 0.997
# Validation Accuracy = 0.925
#
# EPOCH 16 ...
# Train Accuracy = 0.996
# Validation Accuracy = 0.920
#
# EPOCH 17 ...
# Train Accuracy = 0.995
# Validation Accuracy = 0.929
#
# EPOCH 18 ...
# Train Accuracy = 0.997
# Validation Accuracy = 0.932
#
# EPOCH 19 ...
# Train Accuracy = 0.997
# Validation Accuracy = 0.934
#
# EPOCH 20 ...
# Train Accuracy = 0.997
# Validation Accuracy = 0.929

# %%
x_list = []
y_list = []

for result in resultList:
    x_list.append(result.time)
    y_list.append(result.accuracy)

print(x_list)
print(y_list)
plt.plot(x_list, y_list,'rx')
# Out:
# [797.5747463703156, 778.2491369247437, 774.3211507797241, 805.1437547206879, 770.5448641777039, 737.761367559433, 705.9368121623993, 780.2459013462067, 896.6709215641022, 766.2526550292969, 794.2284226417542, 860.6556198596954, 774.1157341003418, 801.2034747600555, 846.3149683475494, 811.7796936035156, 814.8930656909943, 842.9751930236816, 805.7603101730347, 808.924426317215, 818.7791731357574]
# [0.92108843540118124, 0.94217687074829937, 0.96371882086167804, 0.94943310633267941, 0.94399092970521536, 0.92471655331501346, 0.93718820861678009, 0.94399092970521536, 0.94263038575784419, 0.93106575993453566, 0.94036281206169903, 0.94353741496598642, 0.93446711993812159, 0.95079365079365075, 0.94353741472270214, 0.93718820861678009, 0.93174603201634765, 0.93605442152542317, 0.81587301562973158, 0.94308390022675737, 0.92879818569775885]

# %%
#search for the hyperparameter space for the best result
class OptimizationGroup:
    rate = 0
    batchSize = 1
    conv1Depth = 2
    conv2Depth = 3
    full1Len = 4
    full2Len = 5
    keepProb = 6
    last = 7
    
groupName = {
    OptimizationGroup.rate:'rate',
    OptimizationGroup.batchSize:'batchSize',
    OptimizationGroup.conv1Depth:'conv1Depth',
    OptimizationGroup.conv2Depth:'conv2Depth',
    OptimizationGroup.full1Len:'full1Len',
    OptimizationGroup.full2Len:'full2Len',
    OptimizationGroup.keepProb:'keepProb'
}



sweepRound = 4


for group in range(0,OptimizationGroup.last):
    
    plt.figure()
    
    x_list = []
    y_list = []

    for result in resultList[group*3: group*3 + 3]:

        label = ("rate:" + str('%g' % result.rate) + "__" +
                 "batchSize:" + str(result.batchSize)+ "__" +
                 "conv1Depth" + str(result.conv1Depth)+ "__" +
                 "conv2Depth" + str(result.conv2Depth)+ "__" +
                 "full1Len" + str(result.full1Len)+ "__" +
                 "full2Len" + str(result.full2Len)+ "__" +
                 "keepProb" + str('%g' % result.keepProb) + 
                 "accuracy" + str('%.3f' % result.accuracy))
        
        plt.plot(range(0,result.accuracyList.__len__()), result.accuracyList, label = label)
        
        x_list.append(result.time)
        y_list.append(result.accuracy)
        
    
    name = "sweep " + groupName[group] + "_ round " + str(sweepRound) 
    
    plt.ylim([0.75,1])
    plt.xlim([0,20])
    plt.legend(bbox_to_anchor=(1.05, 1), loc=3, borderaxespad=0.)
    plt.title(name)
    plt.savefig(name, bbox_inches='tight')
    
    plt.figure()
    plt.plot(x_list, y_list,'rx')
    name = name + "_accuracyVsTime"
    plt.title(name)
    plt.savefig(name, bbox_inches='tight')

# %%
#store round results

f = open('resultList1.pck4', 'wb')
pickle.dump(resultList, f)
f.close()

# %%
print(result.rate)
print(result.batchSize)
print(result.Epochs)
print(result.conv1Depth)
print(result.conv2Depth)
print(result.full1Len)
print(result.full2Len)
print(result.keepProb)
print(result.time)
print(result.accuracy)
print(result.accuracyList)
# Out:
# 0.01
# 128
# 20
# 6
# 25
# 240
# 62
# 0.8
# 818.7791731357574
# 0.928798185698
# [0.61632653055818176, 0.75714285692660444, 0.8256235825231556, 0.84195011367603223, 0.86054421771410639, 0.87256235830367557, 0.8911564626120656, 0.88979591815109427, 0.88934240341186521, 0.907709750593925, 0.90362811794086384, 0.91700680301843585, 0.91224489801324682, 0.92154194987009441, 0.92494331071165958, 0.92040816329233766, 0.92879818569775885, 0.93174603204337914, 0.9340136057395243, 0.92879818569775885]

# %%
class hyperParameters:
    rate = 0.02
    batchSize = 128
    maxEpochs = 20
    conv1_depth = 6
    conv2_depth = 25
    full1_len = 240
    full2_len = 62
    keepProb = 0.5

# %%
class searchParameters:
    minImprovement = 0.001
    autoStop = False

# %%
#run the final model

nnr = NeuralNetworkRunner()
result = nnr.runHyperParameterIteration()
# Out:
# Tensor("MaxPool_74:0", shape=(?, 14, 14, 6), dtype=float32)
# Tensor("MaxPool_75:0", shape=(?, 5, 5, 25), dtype=float32)
# Tensor("dropout_61/mul:0", shape=(?, 240), dtype=float32)
# Tensor("dropout_62/mul:0", shape=(?, 62), dtype=float32)
# Tensor("Divide_188/truediv:0", shape=(?, 43), dtype=float32)
# Tensor("Divide_188/truediv:0", shape=(?, 43), dtype=float32)
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.735
# Validation Accuracy = 0.692
#
# EPOCH 2 ...
# Train Accuracy = 0.840
# Validation Accuracy = 0.821
#
# EPOCH 3 ...
# Train Accuracy = 0.913
# Validation Accuracy = 0.857
#
# EPOCH 4 ...
# Train Accuracy = 0.945
# Validation Accuracy = 0.887
#
# EPOCH 5 ...
# Train Accuracy = 0.956
# Validation Accuracy = 0.902
#
# EPOCH 6 ...
# Train Accuracy = 0.967
# Validation Accuracy = 0.917
#
# EPOCH 7 ...
# Train Accuracy = 0.965
# Validation Accuracy = 0.929
#
# EPOCH 8 ...
# Train Accuracy = 0.976
# Validation Accuracy = 0.935
#
# EPOCH 9 ...
# Train Accuracy = 0.979
# Validation Accuracy = 0.942
#
# EPOCH 10 ...
# Train Accuracy = 0.986
# Validation Accuracy = 0.943
#
# EPOCH 11 ...
# Train Accuracy = 0.984
# Validation Accuracy = 0.946
#
# EPOCH 12 ...
# Train Accuracy = 0.988
# Validation Accuracy = 0.952
#
# EPOCH 13 ...
# Train Accuracy = 0.990
# Validation Accuracy = 0.956
#
# EPOCH 14 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.959
#
# EPOCH 15 ...
# Train Accuracy = 0.989
# Validation Accuracy = 0.958
#
# EPOCH 16 ...
# Train Accuracy = 0.992
# Validation Accuracy = 0.959
#
# EPOCH 17 ...
# Train Accuracy = 0.994
# Validation Accuracy = 0.962
#
# EPOCH 18 ...
# Train Accuracy = 0.993
# Validation Accuracy = 0.960
#
# EPOCH 19 ...
# Train Accuracy = 0.992
# Validation Accuracy = 0.964
#
# EPOCH 20 ...
# Train Accuracy = 0.994
# Validation Accuracy = 0.963
#
# Model saved

# %%
print(result.accuracy)
# Out:
# 0.963265306393

# %%
#Train Accuracy
with tf.Session() as sess:
    nnr.saver.restore(sess, tf.train.latest_checkpoint('.'))
    train_accuracy = nnr.evaluate(X_train_norm, y_train)
    
print("Final Train Accuracy = {:.3f}".format(train_accuracy))
# Out:
# Final Train Accuracy = 0.997

# %%
#Validation Accuracy
with tf.Session() as sess:
    nnr.saver.restore(sess, tf.train.latest_checkpoint('.'))
    validation_accuracy = nnr.evaluate(X_valid_norm, y_valid)
    
print("Final Validation Accuracy = {:.3f}".format(validation_accuracy))
# Out:
# Final Validation Accuracy = 0.963

# %%
with tf.Session() as sess:
    nnr.saver.restore(sess, tf.train.latest_checkpoint('.'))
    test_accuracy = nnr.evaluate(X_test_norm, y_test)
    
print("Test Accuracy = {:.3f}".format(validation_accuracy))
# Out:
# Test Accuracy = 0.963

# %% [markdown]
# ---
#
# ## Step 2.5: Look at results

# %%
with tf.Session() as sess:
    nnr.saver.restore(sess, tf.train.latest_checkpoint('.'))
    logits = sess.run(nnr.logits, 
                        feed_dict={nnr.x: X_valid_norm, nnr.y: y_valid, nnr.keepProb: 1})

# %%
print(logits.shape)
print(y_valid.shape)
# Out:
# (4410, 43)
# (4410,)

# %%
#rows are what it should be, columns are what it is
error_count = np.zeros((n_classes, n_classes))


for i in range(0,y_valid.shape[0]):
    max_index = np.argmax(logits[i])
    if(max_index != y_valid[i]):
        print("incorrect index " + str(i) + ", should be "  + str(y_valid[i]) + ", got " + str(max_index))
        #print(type(y_valid[i]))
        #print(type(max_index))
        #print(error_count.shape)
        error_count[y_valid[i]][max_index] += 1
# Out:
# incorrect index 0, should be 41, got 32
# incorrect index 1, should be 41, got 32
# incorrect index 2, should be 41, got 32
# incorrect index 6, should be 41, got 32
# incorrect index 79, should be 31, got 21
# incorrect index 298, should be 23, got 26
# incorrect index 301, should be 1, got 2
# incorrect index 390, should be 1, got 2
# incorrect index 444, should be 1, got 2
# incorrect index 450, should be 1, got 3
# incorrect index 568, should be 40, got 1
# incorrect index 569, should be 40, got 9
# incorrect index 634, should be 22, got 29
# incorrect index 635, should be 22, got 29
# incorrect index 636, should be 22, got 29
# incorrect index 642, should be 22, got 29
# incorrect index 643, should be 22, got 29
# incorrect index 644, should be 22, got 29
# incorrect index 647, should be 22, got 29
# incorrect index 648, should be 22, got 29
# incorrect index 649, should be 22, got 29
# incorrect index 650, should be 22, got 29
# incorrect index 654, should be 22, got 29
# incorrect index 800, should be 3, got 8
# incorrect index 815, should be 3, got 13
# incorrect index 924, should be 19, got 10
# incorrect index 1320, should be 0, got 8
# incorrect index 1322, should be 0, got 8
# incorrect index 1323, should be 0, got 8
# incorrect index 1334, should be 0, got 4
# incorrect index 1345, should be 0, got 32
# incorrect index 1383, should be 27, got 18
# incorrect index 1384, should be 27, got 18
# incorrect index 1385, should be 27, got 18
# incorrect index 1386, should be 27, got 18
# incorrect index 1406, should be 27, got 24
# incorrect index 1407, should be 27, got 11
# incorrect index 1408, should be 27, got 30
# incorrect index 1409, should be 27, got 24
# incorrect index 1440, should be 24, got 27
# incorrect index 1441, should be 24, got 37
# incorrect index 1442, should be 24, got 18
# incorrect index 1443, should be 24, got 18
# incorrect index 1444, should be 24, got 27
# incorrect index 1451, should be 24, got 27
# incorrect index 1456, should be 24, got 27
# incorrect index 1459, should be 24, got 27
# incorrect index 1461, should be 24, got 18
# incorrect index 1462, should be 24, got 18
# incorrect index 1463, should be 24, got 18
# incorrect index 1467, should be 24, got 18
# incorrect index 1468, should be 24, got 18
# incorrect index 1505, should be 9, got 3
# incorrect index 1672, should be 5, got 2
# incorrect index 1716, should be 5, got 28
# incorrect index 1790, should be 5, got 25
# incorrect index 1795, should be 5, got 42
# incorrect index 1796, should be 5, got 25
# incorrect index 1797, should be 5, got 2
# incorrect index 1972, should be 38, got 18
# incorrect index 2101, should be 8, got 4
# incorrect index 2124, should be 8, got 4
# incorrect index 2157, should be 8, got 2
# incorrect index 2344, should be 10, got 9
# incorrect index 2536, should be 34, got 38
# incorrect index 2660, should be 18, got 10
# incorrect index 2670, should be 18, got 26
# incorrect index 2721, should be 6, got 32
# incorrect index 2858, should be 13, got 18
# incorrect index 2867, should be 13, got 35
# incorrect index 3000, should be 7, got 8
# incorrect index 3099, should be 7, got 8
# incorrect index 3100, should be 7, got 8
# incorrect index 3240, should be 21, got 29
# incorrect index 3241, should be 21, got 24
# incorrect index 3242, should be 21, got 25
# incorrect index 3243, should be 21, got 29
# incorrect index 3244, should be 21, got 31
# incorrect index 3245, should be 21, got 31
# incorrect index 3246, should be 21, got 31
# incorrect index 3247, should be 21, got 31
# incorrect index 3248, should be 21, got 31
# incorrect index 3249, should be 21, got 31
# incorrect index 3250, should be 21, got 31
# incorrect index 3251, should be 21, got 31
# incorrect index 3252, should be 21, got 31
# incorrect index 3253, should be 21, got 31
# incorrect index 3254, should be 21, got 31
# incorrect index 3257, should be 21, got 31
# incorrect index 3258, should be 21, got 31
# incorrect index 3259, should be 21, got 31
# incorrect index 3260, should be 21, got 31
# incorrect index 3261, should be 21, got 31
# incorrect index 3262, should be 21, got 31
# incorrect index 3263, should be 21, got 31
# incorrect index 3264, should be 21, got 31
# incorrect index 3265, should be 21, got 31
# incorrect index 3266, should be 21, got 31
# incorrect index 3267, should be 21, got 31
# incorrect index 3268, should be 21, got 31
# incorrect index 3269, should be 21, got 31
# incorrect index 3270, should be 21, got 19
# incorrect index 3271, should be 21, got 19
# incorrect index 3272, should be 21, got 31
# incorrect index 3273, should be 21, got 31
# incorrect index 3279, should be 21, got 31
# incorrect index 3280, should be 21, got 31
# incorrect index 3300, should be 20, got 23
# incorrect index 3301, should be 20, got 23
# incorrect index 3302, should be 20, got 23
# incorrect index 3311, should be 20, got 28
# incorrect index 3330, should be 20, got 18
# incorrect index 3331, should be 20, got 29
# incorrect index 3333, should be 20, got 25
# incorrect index 3334, should be 20, got 11
# incorrect index 3335, should be 20, got 29
# incorrect index 3337, should be 20, got 18
# incorrect index 3338, should be 20, got 18
# incorrect index 3340, should be 20, got 30
# incorrect index 3341, should be 20, got 38
# incorrect index 3342, should be 20, got 38
# incorrect index 3347, should be 20, got 18
# incorrect index 3352, should be 20, got 23
# incorrect index 3354, should be 20, got 23
# incorrect index 3356, should be 20, got 23
# incorrect index 3358, should be 20, got 23
# incorrect index 3360, should be 33, got 39
# incorrect index 3361, should be 33, got 39
# incorrect index 3408, should be 33, got 14
# incorrect index 3414, should be 33, got 15
# incorrect index 3416, should be 33, got 15
# incorrect index 3417, should be 33, got 3
# incorrect index 3419, should be 33, got 15
# incorrect index 3603, should be 12, got 13
# incorrect index 3606, should be 12, got 13
# incorrect index 4106, should be 2, got 3
# incorrect index 4110, should be 2, got 5
# incorrect index 4111, should be 2, got 3
# incorrect index 4112, should be 2, got 3
# incorrect index 4117, should be 2, got 1
# incorrect index 4141, should be 2, got 1
# incorrect index 4143, should be 2, got 4
# incorrect index 4144, should be 2, got 1
# incorrect index 4154, should be 2, got 1
# incorrect index 4165, should be 2, got 1
# incorrect index 4171, should be 2, got 4
# incorrect index 4203, should be 2, got 5
# incorrect index 4290, should be 25, got 30
# incorrect index 4291, should be 25, got 18
# incorrect index 4292, should be 25, got 30
# incorrect index 4297, should be 25, got 33
# incorrect index 4298, should be 25, got 29
# incorrect index 4299, should be 25, got 29
# incorrect index 4300, should be 25, got 29
# incorrect index 4301, should be 25, got 29
# incorrect index 4303, should be 25, got 23
# incorrect index 4304, should be 25, got 23
# incorrect index 4305, should be 25, got 23
# incorrect index 4306, should be 25, got 29
# incorrect index 4307, should be 25, got 23
# incorrect index 4308, should be 25, got 30
# incorrect index 4386, should be 25, got 23

# %%
#print common misconceptions

threshold = 5

for i in range(0, n_classes):
    for j in range(0, n_classes):
        if error_count[i][j] >= threshold:
            print("Class " + str(i) + " is incorrectly identified as " + str(j) + " " + str(error_count[i][j]) + " times.")
# Out:
# Class 2 is incorrectly identified as 1 5.0 times.
# Class 20 is incorrectly identified as 23 7.0 times.
# Class 21 is incorrectly identified as 31 28.0 times.
# Class 22 is incorrectly identified as 29 11.0 times.
# Class 24 is incorrectly identified as 18 7.0 times.
# Class 24 is incorrectly identified as 27 5.0 times.
# Class 25 is incorrectly identified as 23 5.0 times.
# Class 25 is incorrectly identified as 29 5.0 times.

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images
# Looks like the hardest to identify are
# - 8 (speed limit 120)
# - 41 (End of no passing)
# - 2 (speed limit 50)
# - 22 (bumpy road)
# - 33 (right turn ahead)

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.
import os
import matplotlib.image as mpimg

imageList = os.listdir("test_images\scaled")

print(imageList)

X_new = np.zeros((5,32,32,3))


for i in range(0,imageList.__len__()):
    image = imageList[i]
    image = mpimg.imread( "test_images/scaled/" +image)

    image_np = np.array(image)
    X_new[i] = np.copy(image_np)
    
    plt.figure()
    plt.imshow(image_np)

print(X_new.shape)
X_new_norm = processImage(X_new)
y_new = np.array([8,2,22,41,33])
# Out:
# ['120kph.jpg', '50kph.jpg', 'BumpyRoad.jpg', 'end_no_passing.jpg', 'RightTurn.jpg']
# (5, 32, 32, 3)

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
### Run the predictions here and use the model to output the prediction for each image.
### Make sure to pre-process the images with the same pre-processing pipeline used earlier.
### Feel free to use as many code cells as needed.

# %%
#get logits

with tf.Session() as sess:
    nnr.saver.restore(sess, tf.train.latest_checkpoint('.'))
    logits= sess.run(nnr.logits, 
                        feed_dict={nnr.x: X_new_norm, nnr.y: y_new, nnr.keepProb: 1})

# %%
print(logits)
# Out:
# [[  3.41077971e+00   2.03164101e+00  -7.63256788e+00  -1.16644049e+01
#     1.28842945e+01   4.26065254e+00  -2.16147289e+01   7.94878769e+00
#     2.09281101e+01  -3.67270470e+01  -4.33417816e+01  -3.06199627e+01
#    -3.56784973e+01  -4.35900650e+01  -2.69659328e+01  -2.19362855e+00
#    -4.15603485e+01  -2.58004208e+01  -2.61297226e+01  -4.44963188e+01
#    -2.54096622e+01  -4.99276924e+01  -5.49618950e+01  -5.44425850e+01
#    -3.94297295e+01  -4.28648262e+01  -2.18017120e+01  -3.15083561e+01
#    -2.86729393e+01  -2.00891171e+01  -3.37938957e+01  -3.54620361e+01
#    -1.32303772e+01  -4.64528275e+01  -5.52352028e+01  -4.25839806e+01
#    -3.51739616e+01  -4.38067703e+01  -3.90883980e+01  -4.32650948e+01
#    -2.22561264e+01  -5.82480316e+01  -5.88131905e+01]
#  [ -7.75931015e+01   6.70042944e+00   4.28048477e+01   6.27701759e+00
#    -2.47633038e+01   1.25780287e+01  -4.65735130e+01  -9.49517250e+00
#    -4.87761345e+01  -4.61840553e+01  -2.58950806e+01  -7.06855164e+01
#    -5.43432770e+01  -2.45612106e+01  -5.29349251e+01  -1.52918911e+01
#    -9.51446152e+01  -7.22939377e+01  -1.08628578e+02  -4.53004456e+01
#    -8.07406540e+01  -4.00151329e+01  -1.43861542e+02  -5.78208885e+01
#    -1.25378754e+02  -4.66746597e+01  -7.68208313e+01  -1.14686058e+02
#    -9.89761353e+01  -5.58383980e+01  -7.73625793e+01  -2.40801296e+01
#    -6.81546860e+01  -2.88339653e+01  -8.11799240e+01  -4.02459068e+01
#    -8.86427917e+01  -5.25011215e+01  -6.40602493e+01  -6.98297272e+01
#    -4.19894562e+01  -1.11459251e+02  -6.08386421e+01]
#  [ -1.70345955e+01  -8.27030468e+00  -8.00771236e+00   5.27646959e-01
#    -1.18549738e+01  -1.97130835e+00  -1.72190495e+01  -1.39553623e+01
#    -7.42293930e+00  -2.16302919e+00  -3.80957294e+00  -1.51477070e+01
#    -1.07248583e+01   1.07097954e-01  -2.30157539e-01  -2.05645800e+00
#    -1.96770878e+01  -1.05887680e+01  -1.22722454e+01  -1.17840624e+01
#    -3.61324096e+00  -1.09503536e+01   9.39912140e-01  -5.01594687e+00
#    -9.36516953e+00   2.73777813e-01  -8.31581306e+00  -2.26812649e+01
#    -2.83353758e+00   2.28645730e+00  -4.69208288e+00  -9.30240917e+00
#    -1.19282036e+01  -7.46057701e+00  -2.52541804e+00  -5.40129757e+00
#    -9.89750862e+00  -1.48642359e+01  -5.80646944e+00  -1.41216316e+01
#    -1.88118534e+01  -1.23664274e+01  -1.78666725e+01]
#  [ -6.41187572e+00  -8.10521841e-01  -1.83577938e+01  -1.79829633e+00
#    -2.53998528e+01  -8.87211514e+00   4.31297874e+00  -9.51645565e+00
#    -1.65712337e+01  -8.86807919e+00  -1.14113483e+01   3.79849839e+00
#     5.02982521e+00  -2.29354739e+00  -1.60056820e+01  -1.44929619e+01
#    -6.17254972e+00  -9.64498234e+00  -1.07684002e+01  -1.61187801e+01
#    -8.28959274e+00  -1.82109184e+01  -2.80015411e+01  -9.26559925e+00
#    -2.35751839e+01  -1.02646770e+01  -6.44350147e+00  -1.52000589e+01
#    -5.75002670e+00  -1.37513428e+01  -4.97576332e+00  -2.26590309e+01
#     5.82695580e+00  -2.11071072e+01  -6.75152302e+00  -1.37144995e+01
#    -1.04203892e+01  -2.40825996e+01  -8.03373051e+00  -3.61392250e+01
#    -2.90533495e+00   5.76520491e+00   3.81076884e+00]
#  [ -5.06861992e+01  -1.62901382e+01  -1.31837234e+01  -1.87194653e+01
#    -2.94970989e+01  -4.10707970e+01  -5.82840004e+01  -3.89580994e+01
#    -5.79847832e+01  -2.23349094e+01  -4.31508560e+01  -2.61742687e+01
#    -2.24590378e+01  -1.07535286e+01  -5.13119850e+01  -2.02393932e+01
#    -5.14337387e+01  -2.04210224e+01  -2.86763878e+01  -2.94303989e+01
#    -3.94754181e+01  -1.91183243e+01  -6.34556198e+01  -3.43890877e+01
#    -6.21976967e+01  -4.46134415e+01  -3.08061066e+01  -4.47380447e+01
#    -3.88965950e+01  -2.90853901e+01  -2.03893185e+01  -1.44436016e+01
#    -3.37275810e+01   3.03766556e+01  -1.33627415e+01  -1.60115981e+00
#    -2.91530895e+01  -3.93985057e+00  -1.67530499e+01   5.26954603e+00
#     9.97782993e+00  -3.75923119e+01  -5.92865524e+01]]

# %%
#find softmax

#print(logits)
print(type(logits))
print(logits.shape)

logits_tf = tf.constant(logits, dtype='float32')

#logits_softMax = tf.nn.softmax()
with tf.Session() as sess:
    logitsSoftMax = sess.run(tf.nn.softmax(logits_tf))

print(logitsSoftMax)
# Out:
# <class 'numpy.ndarray'>
# (5, 43)
# [[  2.46705998e-08   6.21194030e-09   3.94561283e-13   7.00020130e-15
#     3.20977648e-04   5.77131338e-08   3.33994464e-19   2.30680780e-06
#     9.99676585e-01   9.13150008e-26   1.22405523e-28   4.10030272e-23
#     2.60569188e-25   9.54933002e-29   1.58394808e-21   9.08272346e-11
#     7.26888139e-28   5.08061643e-21   3.65513341e-21   3.85824856e-29
#     7.50966663e-21   1.68878607e-31   1.09963419e-33   1.84833924e-33
#     6.12043087e-27   1.97214324e-28   2.77034833e-19   1.68652040e-23
#     2.87340351e-22   1.53569193e-18   1.71551116e-24   3.23542253e-25
#     1.46223711e-15   5.45369645e-30   8.36666094e-34   2.61160891e-28
#     4.31557304e-25   7.68880766e-29   8.61034205e-27   1.32161213e-28
#     1.75867154e-19   4.11243341e-35   2.33696313e-35]
#  [  0.00000000e+00   2.08953552e-16   1.00000000e+00   1.36824580e-16
#     4.52401282e-30   7.45864077e-14   0.00000000e+00   1.93370697e-23
#     0.00000000e+00   0.00000000e+00   1.45881510e-30   0.00000000e+00
#     0.00000000e+00   5.53723027e-30   0.00000000e+00   5.87362349e-26
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   1.07582360e-36   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   8.95823744e-30
#     0.00000000e+00   7.72076738e-32   0.00000000e+00   8.54116749e-37
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     1.49383192e-37   0.00000000e+00   0.00000000e+00]
#  [  2.23256880e-09   1.42918343e-05   1.85836216e-05   9.46214795e-02
#     3.96539065e-07   7.77512090e-03   1.85651083e-09   4.85398957e-08
#     3.33498647e-05   6.41865190e-03   1.23696961e-03   1.47322847e-08
#     1.22769052e-06   6.21366091e-02   4.43485454e-02   7.14047486e-03
#     1.58922361e-10   1.40666964e-06   2.61256531e-07   4.25679161e-07
#     1.50530646e-03   9.79845254e-07   1.42900646e-01   3.70200811e-04
#     4.78183074e-06   7.34067038e-02   1.36560129e-05   7.87929704e-12
#     3.28280963e-03   5.49327493e-01   5.11787599e-04   5.09155780e-06
#     3.68538338e-07   3.21179796e-05   4.46745753e-03   2.51815189e-04
#     2.80803351e-06   1.95604848e-08   1.67925944e-04   4.11044603e-08
#     3.77530035e-10   2.37774060e-07   9.71490111e-10]
#  [  1.68145539e-06   4.55325906e-04   1.09053365e-11   1.69565465e-04
#     9.53480255e-15   1.43620682e-07   7.64593333e-02   7.54020988e-08
#     6.50926882e-11   1.44201493e-07   1.13355343e-08   4.57082391e-02
#     1.56586006e-01   1.03336213e-04   1.14590400e-10   5.20132826e-10
#     2.13610747e-06   6.63078552e-08   2.15610942e-08   1.02336445e-10
#     2.57159911e-07   1.26306665e-11   7.06987855e-16   9.69011609e-08
#     5.91228523e-14   3.56808343e-08   1.62911022e-06   2.56463434e-10
#     3.25928818e-06   1.09193132e-09   7.06937590e-06   1.47786758e-13
#     3.47490042e-01   6.97633683e-13   1.19723234e-06   1.13291310e-09
#     3.05358547e-08   3.55948757e-14   3.32141212e-07   2.06662869e-19
#     5.60475819e-05   3.26681316e-01   4.62725535e-02]
#  [  6.23521119e-36   5.40591167e-21   1.20772415e-19   4.76238837e-22
#     9.93477403e-27   9.34904570e-32   0.00000000e+00   7.73211878e-31
#     0.00000000e+00   1.28132413e-23   1.16790477e-32   2.75578154e-25
#     1.13174845e-23   1.37210693e-18   3.33482094e-36   1.04166596e-22
#     2.95254959e-36   8.68659550e-23   2.25729929e-26   1.06200623e-26
#     4.60924548e-31   3.19597492e-22   0.00000000e+00   7.45750287e-29
#     0.00000000e+00   2.70529519e-33   2.68326781e-27   2.38836189e-33
#     8.22257546e-31   1.49955540e-26   8.96637228e-23   3.42616917e-20
#     1.44505846e-28   1.00000000e+00   1.00976904e-19   1.29482513e-14
#     1.40139106e-26   1.24890974e-15   3.40273549e-21   1.24773126e-11
#     1.38325473e-09   3.03008044e-30   1.14752892e-39]]

# %%
print(np.sum(logitsSoftMax, axis = 1))
# Out:
# [ 0.99999994  1.          1.00000012  0.99999994  1.        ]

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.

print(logitsSoftMax)
a = np.max(logitsSoftMax,axis=1)
print(a)

for i in range(0,y_new.__len__()):
    max_index = np.argmax(logitsSoftMax[i])
    print("index " + str(i) + ", should be "  + str(y_new[i]) + ", got " + str(max_index))
# Out:
# [[  2.46705998e-08   6.21194030e-09   3.94561283e-13   7.00020130e-15
#     3.20977648e-04   5.77131338e-08   3.33994464e-19   2.30680780e-06
#     9.99676585e-01   9.13150008e-26   1.22405523e-28   4.10030272e-23
#     2.60569188e-25   9.54933002e-29   1.58394808e-21   9.08272346e-11
#     7.26888139e-28   5.08061643e-21   3.65513341e-21   3.85824856e-29
#     7.50966663e-21   1.68878607e-31   1.09963419e-33   1.84833924e-33
#     6.12043087e-27   1.97214324e-28   2.77034833e-19   1.68652040e-23
#     2.87340351e-22   1.53569193e-18   1.71551116e-24   3.23542253e-25
#     1.46223711e-15   5.45369645e-30   8.36666094e-34   2.61160891e-28
#     4.31557304e-25   7.68880766e-29   8.61034205e-27   1.32161213e-28
#     1.75867154e-19   4.11243341e-35   2.33696313e-35]
#  [  0.00000000e+00   2.08953552e-16   1.00000000e+00   1.36824580e-16
#     4.52401282e-30   7.45864077e-14   0.00000000e+00   1.93370697e-23
#     0.00000000e+00   0.00000000e+00   1.45881510e-30   0.00000000e+00
#     0.00000000e+00   5.53723027e-30   0.00000000e+00   5.87362349e-26
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   1.07582360e-36   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   8.95823744e-30
#     0.00000000e+00   7.72076738e-32   0.00000000e+00   8.54116749e-37
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     1.49383192e-37   0.00000000e+00   0.00000000e+00]
#  [  2.23256880e-09   1.42918343e-05   1.85836216e-05   9.46214795e-02
#     3.96539065e-07   7.77512090e-03   1.85651083e-09   4.85398957e-08
#     3.33498647e-05   6.41865190e-03   1.23696961e-03   1.47322847e-08
#     1.22769052e-06   6.21366091e-02   4.43485454e-02   7.14047486e-03
#     1.58922361e-10   1.40666964e-06   2.61256531e-07   4.25679161e-07
#     1.50530646e-03   9.79845254e-07   1.42900646e-01   3.70200811e-04
#     4.78183074e-06   7.34067038e-02   1.36560129e-05   7.87929704e-12
#     3.28280963e-03   5.49327493e-01   5.11787599e-04   5.09155780e-06
#     3.68538338e-07   3.21179796e-05   4.46745753e-03   2.51815189e-04
#     2.80803351e-06   1.95604848e-08   1.67925944e-04   4.11044603e-08
#     3.77530035e-10   2.37774060e-07   9.71490111e-10]
#  [  1.68145539e-06   4.55325906e-04   1.09053365e-11   1.69565465e-04
#     9.53480255e-15   1.43620682e-07   7.64593333e-02   7.54020988e-08
#     6.50926882e-11   1.44201493e-07   1.13355343e-08   4.57082391e-02
#     1.56586006e-01   1.03336213e-04   1.14590400e-10   5.20132826e-10
#     2.13610747e-06   6.63078552e-08   2.15610942e-08   1.02336445e-10
#     2.57159911e-07   1.26306665e-11   7.06987855e-16   9.69011609e-08
#     5.91228523e-14   3.56808343e-08   1.62911022e-06   2.56463434e-10
#     3.25928818e-06   1.09193132e-09   7.06937590e-06   1.47786758e-13
#     3.47490042e-01   6.97633683e-13   1.19723234e-06   1.13291310e-09
#     3.05358547e-08   3.55948757e-14   3.32141212e-07   2.06662869e-19
#     5.60475819e-05   3.26681316e-01   4.62725535e-02]
#  [  6.23521119e-36   5.40591167e-21   1.20772415e-19   4.76238837e-22
#     9.93477403e-27   9.34904570e-32   0.00000000e+00   7.73211878e-31
#     0.00000000e+00   1.28132413e-23   1.16790477e-32   2.75578154e-25
#     1.13174845e-23   1.37210693e-18   3.33482094e-36   1.04166596e-22
#     2.95254959e-36   8.68659550e-23   2.25729929e-26   1.06200623e-26
#     4.60924548e-31   3.19597492e-22   0.00000000e+00   7.45750287e-29
#     0.00000000e+00   2.70529519e-33   2.68326781e-27   2.38836189e-33
#     8.22257546e-31   1.49955540e-26   8.96637228e-23   3.42616917e-20
#     1.44505846e-28   1.00000000e+00   1.00976904e-19   1.29482513e-14
#     1.40139106e-26   1.24890974e-15   3.40273549e-21   1.24773126e-11
#     1.38325473e-09   3.03008044e-30   1.14752892e-39]]
# [ 0.99967659  1.          0.54932749  0.34749004  1.        ]
# index 0, should be 8, got 8
# index 1, should be 2, got 2
# index 2, should be 22, got 29
# index 3, should be 41, got 32
# index 4, should be 33, got 33

# %%
print(np.max(X_new_norm[1]))
print(np.min(X_new_norm[1]))
# Out:
# 0.5
# -0.5

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tf.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.

with tf.Session() as sess:
    nnr.saver.restore(sess, tf.train.latest_checkpoint('.'))
    top_vals = sess.run(tf.nn.top_k(tf.constant(logitsSoftMax), k=5))

# %%
print(top_vals)
# Out:
# TopKV2(values=array([[  9.99676585e-01,   3.20977648e-04,   2.30680780e-06,
#           5.77131338e-08,   2.46705998e-08],
#        [  1.00000000e+00,   7.45864077e-14,   2.08953552e-16,
#           1.36824580e-16,   1.93370697e-23],
#        [  5.49327493e-01,   1.42900646e-01,   9.46214795e-02,
#           7.34067038e-02,   6.21366091e-02],
#        [  3.47490042e-01,   3.26681316e-01,   1.56586006e-01,
#           7.64593333e-02,   4.62725535e-02],
#        [  1.00000000e+00,   1.38325473e-09,   1.24773126e-11,
#           1.29482513e-14,   1.24890974e-15]], dtype=float32), indices=array([[ 8,  4,  7,  5,  0],
#        [ 2,  5,  1,  3,  7],
#        [29, 22,  3, 25, 13],
#        [32, 41, 12,  6, 42],
#        [33, 40, 39, 35, 37]]))

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ---
#
# ## Step 4 (Optional): Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it may be having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")
